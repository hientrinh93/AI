# %% [markdown]
# <a href="https://colab.research.google.com/github/hientrinh93/AI/blob/main/Copy_of_Token_classification_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Named entity recognition (NER), or token-classification, or entity extraction**, is the first step of information extraction that classifies the text into defined categories, including the persons names, organizations, locations, times, percentages etc.
#
# In this tutorial, an URL website will be scraped to extract information: https://www.cnbc.com/2019/12/31/the-stock-market-boomed-in-2019-heres-how-it-happened.html, using 3 different methods NLTK, SpaCy, BERT model on Hugging Face.

# %%
# libraries required
# !pip install transformers
# !pip install language_tool_python

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import tree2conlltags

import spacy
from spacy import displacy
import en_core_web_sm

from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

from bs4 import BeautifulSoup
import requests
import re
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.17.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.49)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: language_tool_python in /usr/local/lib/python3.7/dist-packages (2.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from language_tool_python) (4.63.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from language_tool_python) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (2.10)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# web scraping
url = "https://www.cnbc.com/2019/12/31/the-stock-market-boomed-in-2019-heres-how-it-happened.html"
html_content = requests.get(url).content
soup = BeautifulSoup(html_content, "html.parser")

# %%
# extract the main content
job_elements = soup.find_all("p")
content = ''
for job_element in job_elements:
    content += job_element.text + ' '
print (content)
# Out:
#  It was a year that began with investors courting a bear market and ended with the biggest gains from stocks since 2013. Twelve months ago, few could have imagined the S&P 500 delivering a gain of more than 28% in 2019. It was a performance that flirted with the 31% gain of 1997, and one that came very close to topping the 29.6% return of 2013.  The tech-heavy Nasdaq did even better, posting a gain of 35% as money flowed to the tech giants, cementing Apple and Microsoft's position as trillion-dollar companies. The Dow Jones Industrial Average was up 22%.  It was a year filled with fears that were never realized: a global economic slowdown, disruptive trade wars and potential missteps from Federal Reserve policy. The year also revealed an unforeseen boom in the tech sector that drove the major stock indexes ever higher. One of the key's to the market's 2019 success was starting from a low base.  A steep sell-off in December 2018 left the S&P 500 just 0.2% from officially hitting a bear market, defined as a 20% decline from its closing peak. The S&P 500 ended 2018 with a loss of more than 6%, closing at 2,485.74 on Dec. 31, 2018. In the final hours of trading in 2019, it's trading around 3,220. For perspective, the S&P is finishing 2019 about 10% above 2018's high of roughly 2,900, which is close to the average return for the S&P 500 over 90 years of 9.8%. Much of the stock market's gains in 2019 can be attributed to a dramatic policy shift at the Federal Reserve. The Fed raised rates four times in 2018, including a December 2018 hike that took its key rate to 2.5 percent. It was a different story in 2019, when after a change of heart the Fed lowered rates three times. Falling interest rates sent investors on a quest for yield, forcing more money into stocks expected to appreciate, pay dividends or both. The Fed's key rate is now back to a range of 1.50% to 1.75%. Additionally, the Fed has said it expects to leave rates unchanged for 2020, giving investors clarity on top of what remain historically low rates. Fed Chairman Jerome Powell described the central bank's moves as "insurance" rate cuts. The Fed wanted to ensure a slowing global economy didn't drag down the U.S. One of the biggest uncertainties for global economic growth was President Donald Trump's trade negotiations with China as well as the re-crafting of the North American Free Trade Agreement with Canada and Mexico. Indeed, trade war headlines dominated the financial news throughout most of the year. Trump's tariffs and threats of more tariffs often sent indexes frightfully lower. Then his pronouncements, usually by tweet, that deals were coming together, would send markets back even higher. Over the course of the year, however, the trade war had only transient effects on the stock market. As the year came to a close, the House passed the United States-Mexico-Canada Agreement, which is Trump's replacement for NAFTA, and the Senate is expected to pass it soon. Also, the Trump administration has come to a phase one trade agreement with China. When U.S. and China officials sign the deal in the coming weeks, it hardly means an end to what are sure to be difficult negotiations, but the initial agreement has marked a pause in trade war escalation, and that has sharply boosted markets. Throughout 2019, investors fretted a slowing global economy. Some of those fears stemmed from disruptive trade wars and tariffs, another was the U.K.'s plans to depart from the European Union, often called Brexit, and fears of voters around the world shifting to the far left. The International Monetary Fund has recently downgraded its 2019 estimate for global economic growth to 3%, the lowest since the financial crisis. But as the year came to a close, it appeared the U.K. would more likely achieve a negotiated exit from the EU versus a hard one and trade tensions eased with the phase one deal between the U.S. and China. And some economists are expressing hopes that the global economic slowd ...

# %%
# word tokenization and part-of-speech tagging to the sentence
# Part Of Speech (POS) Tagging: https://www.ibm.com/docs/en/wca/3.5.0?topic=analytics-part-speech-tag-sets**
def postag(sentence):
    sentence = word_tokenize(sentence)
    sentence = pos_tag(sentence)
    return sentence

# %%
preprocess = postag(content)
preprocess
# Out:
# [('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('that', 'WDT'),
#  ('began', 'VBD'),
#  ('with', 'IN'),
#  ('investors', 'NNS'),
#  ('courting', 'VBG'),
#  ('a', 'DT'),
#  ('bear', 'JJ'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ended', 'VBD'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('biggest', 'JJS'),
#  ('gains', 'NNS'),
#  ('from', 'IN'),
#  ('stocks', 'NNS'),
#  ('since', 'IN'),
#  ('2013', 'CD'),
#  ('.', '.'),
#  ('Twelve', 'CD'),
#  ('months', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('few', 'JJ'),
#  ('could', 'MD'),
#  ('have', 'VB'),
#  ('imagined', 'VBN'),
#  ('the', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('500', 'CD'),
#  ('delivering', 'VBG'),
#  ('a', 'DT'),
#  ('gain', 'NN'),
#  ('of', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('28', 'CD'),
#  ('%', 'NN'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('performance', 'NN'),
#  ('that', 'WDT'),
#  ('flirted', 'VBD'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('31', 'CD'),
#  ('%', 'NN'),
#  ('gain', 'NN'),
#  ('of', 'IN'),
#  ('1997', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('one', 'CD'),
#  ('that', 'WDT'),
#  ('came', 'VBD'),
#  ('very', 'RB'),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('topping', 'VBG'),
#  ('the', 'DT'),
#  ('29.6', 'CD'),
#  ('%', 'NN'),
#  ('return', 'NN'),
#  ('of', 'IN'),
#  ('2013', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('tech-heavy', 'JJ'),
#  ('Nasdaq', 'NNP'),
#  ('did', 'VBD'),
#  ('even', 'RB'),
#  ('better', 'RBR'),
#  (',', ','),
#  ('posting', 'VBG'),
#  ('a', 'DT'),
#  ('gain', 'NN'),
#  ('of', 'IN'),
#  ('35', 'CD'),
#  ('%', 'NN'),
#  ('as', 'IN'),
#  ('money', 'NN'),
#  ('flowed', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('tech', 'JJ'),
#  ('giants', 'NNS'),
#  (',', ','),
#  ('cementing', 'VBG'),
#  ('Apple', 'NNP'),
#  ('and', 'CC'),
#  ('Microsoft', 'NNP'),
#  ("'s", 'POS'),
#  ('position', 'NN'),
#  ('as', 'IN'),
#  ('trillion-dollar', 'JJ'),
#  ('companies', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Dow', 'NNP'),
#  ('Jones', 'NNP'),
#  ('Industrial', 'NNP'),
#  ('Average', 'NNP'),
#  ('was', 'VBD'),
#  ('up', 'RB'),
#  ('22', 'CD'),
#  ('%', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('filled', 'VBN'),
#  ('with', 'IN'),
#  ('fears', 'NNS'),
#  ('that', 'WDT'),
#  ('were', 'VBD'),
#  ('never', 'RB'),
#  ('realized', 'VBN'),
#  (':', ':'),
#  ('a', 'DT'),
#  ('global', 'JJ'),
#  ('economic', 'JJ'),
#  ('slowdown', 'NN'),
#  (',', ','),
#  ('disruptive', 'JJ'),
#  ('trade', 'NN'),
#  ('wars', 'NNS'),
#  ('and', 'CC'),
#  ('potential', 'JJ'),
#  ('missteps', 'NNS'),
#  ('from', 'IN'),
#  ('Federal', 'NNP'),
#  ('Reserve', 'NNP'),
#  ('policy', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('year', 'NN'),
#  ('also', 'RB'),
#  ('revealed', 'VBD'),
#  ('an', 'DT'),
#  ('unforeseen', 'JJ'),
#  ('boom', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('tech', 'NN'),
#  ('sector', 'NN'),
#  ('that', 'WDT'),
#  ('drove', 'VBD'),
#  ('the', 'DT'),
#  ('major', 'JJ'),
#  ('stock', 'NN'),
#  ('indexes', 'NNS'),
#  ('ever', 'RB'),
#  ('higher', 'JJR'),
#  ('.', '.'),
#  ('One', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('key', 'NN'),
#  ("'s", 'POS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('market', 'NN'),
#  ("'s", 'POS'),
#  ('2019', 'CD'),
#  ('success', 'NN'),
#  ('was', 'VBD'),
#  ('starting', 'VBG'),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('low', 'JJ'),
#  ('base', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('steep', 'JJ'),
#  ('sell-off', 'NN'),
#  ('in', 'IN'),
#  ('December', 'NNP'),
#  ('2018', 'CD'),
#  ('left', 'VBD'),
#  ('the', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('500', 'CD'),
#  ('just', 'RB'),
#  ('0.2', 'CD'),
#  ('%', 'NN'),
#  ('from', 'IN'),
#  ('officially', 'RB'),
#  ('hitting', 'VBG'),
#  ('a', 'DT'),
#  ('bear', 'JJ'),
#  ('market', 'NN'),
#  (',', ','),
#  ('defined', 'VBD'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('20', 'CD'),
#  ('%', 'NN'),
#  ('decline', 'NN'),
#  ('from', 'IN'),
#  ('its', 'PRP$'),
#  ('closing', 'NN'),
#  ('peak', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('500', 'CD'),
#  ('ended', 'VBD'),
#  ('2018', 'CD'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('loss', 'NN'),
#  ('of', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('6', 'CD'),
#  ('%', 'NN'),
#  (',', ','),
#  ('closing', 'VBG'),
#  ('at', 'IN'),
#  ('2,485.74', 'CD'),
#  ('on', 'IN'),
#  ('Dec.', 'NNP'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2018', 'CD'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('final', 'JJ'),
#  ('hours', 'NNS'),
#  ('of', 'IN'),
#  ('trading', 'NN'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('trading', 'VBG'),
#  ('around', 'RB'),
#  ('3,220', 'CD'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('perspective', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('is', 'VBZ'),
#  ('finishing', 'JJ'),
#  ('2019', 'CD'),
#  ('about', 'IN'),
#  ('10', 'CD'),
#  ('%', 'NN'),
#  ('above', 'IN'),
#  ('2018', 'CD'),
#  ("'s", 'POS'),
#  ('high', 'JJ'),
#  ('of', 'IN'),
#  ('roughly', 'RB'),
#  ('2,900', 'CD'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('average', 'JJ'),
#  ('return', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('500', 'CD'),
#  ('over', 'IN'),
#  ('90', 'CD'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('9.8', 'CD'),
#  ('%', 'NN'),
#  ('.', '.'),
#  ('Much', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  ('market', 'NN'),
#  ("'s", 'POS'),
#  ('gains', 'NNS'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('attributed', 'VBN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('dramatic', 'JJ'),
#  ('policy', 'NN'),
#  ('shift', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Federal', 'NNP'),
#  ('Reserve', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Fed', 'NNP'),
#  ('raised', 'VBD'),
#  ('rates', 'NNS'),
#  ('four', 'CD'),
#  ('times', 'NNS'),
#  ('in', 'IN'),
#  ('2018', 'CD'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('a', 'DT'),
#  ('December', 'NNP'),
#  ('2018', 'CD'),
#  ('hike', 'NN'),
#  ('that', 'WDT'),
#  ('took', 'VBD'),
#  ('its', 'PRP$'),
#  ('key', 'JJ'),
#  ('rate', 'NN'),
#  ('to', 'TO'),
#  ('2.5', 'CD'),
#  ('percent', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('different', 'JJ'),
#  ('story', 'NN'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('after', 'IN'),
#  ('a', 'DT'),
#  ('change', 'NN'),
#  ('of', 'IN'),
#  ('heart', 'NN'),
#  ('the', 'DT'),
#  ('Fed', 'NNP'),
#  ('lowered', 'VBD'),
#  ('rates', 'NNS'),
#  ('three', 'CD'),
#  ('times', 'NNS'),
#  ('.', '.'),
#  ('Falling', 'VBG'),
#  ('interest', 'NN'),
#  ('rates', 'NNS'),
#  ('sent', 'VBD'),
#  ('investors', 'NNS'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('quest', 'NN'),
#  ('for', 'IN'),
#  ('yield', 'NN'),
#  (',', ','),
#  ('forcing', 'VBG'),
#  ('more', 'JJR'),
#  ('money', 'NN'),
#  ('into', 'IN'),
#  ('stocks', 'NNS'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('appreciate', 'VB'),
#  (',', ','),
#  ('pay', 'VB'),
#  ('dividends', 'NNS'),
#  ('or', 'CC'),
#  ('both', 'DT'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Fed', 'NNP'),
#  ("'s", 'POS'),
#  ('key', 'JJ'),
#  ('rate', 'NN'),
#  ('is', 'VBZ'),
#  ('now', 'RB'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('1.50', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('1.75', 'CD'),
#  ('%', 'NN'),
#  ('.', '.'),
#  ('Additionally', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Fed', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('expects', 'VBZ'),
#  ('to', 'TO'),
#  ('leave', 'VB'),
#  ('rates', 'NNS'),
#  ('unchanged', 'JJ'),
#  ('for', 'IN'),
#  ('2020', 'CD'),
#  (',', ','),
#  ('giving', 'VBG'),
#  ('investors', 'NNS'),
#  ('clarity', 'NN'),
#  ('on', 'IN'),
#  ('top', 'NN'),
#  ('of', 'IN'),
#  ('what', 'WP'),
#  ('remain', 'VBP'),
#  ('historically', 'RB'),
#  ('low', 'JJ'),
#  ('rates', 'NNS'),
#  ('.', '.'),
#  ('Fed', 'NNP'),
#  ('Chairman', 'NNP'),
#  ('Jerome', 'NNP'),
#  ('Powell', 'NNP'),
#  ('described', 'VBD'),
#  ('the', 'DT'),
#  ('central', 'JJ'),
#  ('bank', 'NN'),
#  ("'s", 'POS'),
#  ('moves', 'NNS'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('insurance', 'NN'),
#  ("''", "''"),
#  ('rate', 'NN'),
#  ('cuts', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Fed', 'NNP'),
#  ('wanted', 'VBD'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('a', 'DT'),
#  ('slowing', 'VBG'),
#  ('global', 'JJ'),
#  ('economy', 'NN'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('drag', 'VB'),
#  ('down', 'RP'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('One', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('biggest', 'JJS'),
#  ('uncertainties', 'NNS'),
#  ('for', 'IN'),
#  ('global', 'JJ'),
#  ('economic', 'JJ'),
#  ('growth', 'NN'),
#  ('was', 'VBD'),
#  ('President', 'NNP'),
#  ('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('trade', 'NN'),
#  ('negotiations', 'NNS'),
#  ('with', 'IN'),
#  ('China', 'NNP'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('re-crafting', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('North', 'JJ'),
#  ('American', 'JJ'),
#  ('Free', 'NNP'),
#  ('Trade', 'NNP'),
#  ('Agreement', 'NNP'),
#  ('with', 'IN'),
#  ('Canada', 'NNP'),
#  ('and', 'CC'),
#  ('Mexico', 'NNP'),
#  ('.', '.'),
#  ('Indeed', 'RB'),
#  (',', ','),
#  ('trade', 'NN'),
#  ('war', 'NN'),
#  ('headlines', 'NNS'),
#  ('dominated', 'VBD'),
#  ('the', 'DT'),
#  ('financial', 'JJ'),
#  ('news', 'NN'),
#  ('throughout', 'IN'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('tariffs', 'NNS'),
#  ('and', 'CC'),
#  ('threats', 'NNS'),
#  ('of', 'IN'),
#  ('more', 'JJR'),
#  ('tariffs', 'NNS'),
#  ('often', 'RB'),
#  ('sent', 'VBD'),
#  ('indexes', 'NNS'),
#  ('frightfully', 'RB'),
#  ('lower', 'JJR'),
#  ('.', '.'),
#  ('Then', 'RB'),
#  ('his', 'PRP$'),
#  ('pronouncements', 'NNS'),
#  (',', ','),
#  ('usually', 'RB'),
#  ('by', 'IN'),
#  ('tweet', 'NN'),
#  (',', ','),
#  ('that', 'IN'),
#  ('deals', 'NNS'),
#  ('were', 'VBD'),
#  ('coming', 'VBG'),
#  ('together', 'RB'),
#  (',', ','),
#  ('would', 'MD'),
#  ('send', 'VB'),
#  ('markets', 'NNS'),
#  ('back', 'RB'),
#  ('even', 'RB'),
#  ('higher', 'JJR'),
#  ('.', '.'),
#  ('Over', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  (',', ','),
#  ('however', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('trade', 'NN'),
#  ('war', 'NN'),
#  ('had', 'VBD'),
#  ('only', 'RB'),
#  ('transient', 'JJ'),
#  ('effects', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  ('market', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('came', 'VBD'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('close', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('House', 'NNP'),
#  ('passed', 'VBD'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States-Mexico-Canada', 'NNP'),
#  ('Agreement', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('replacement', 'NN'),
#  ('for', 'IN'),
#  ('NAFTA', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Senate', 'NNP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('pass', 'VB'),
#  ('it', 'PRP'),
#  ('soon', 'RB'),
#  ('.', '.'),
#  ('Also', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Trump', 'NNP'),
#  ('administration', 'NN'),
#  ('has', 'VBZ'),
#  ('come', 'VBN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('phase', 'NN'),
#  ('one', 'CD'),
#  ('trade', 'NN'),
#  ('agreement', 'NN'),
#  ('with', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('U.S.', 'NNP'),
#  ('and', 'CC'),
#  ('China', 'NNP'),
#  ('officials', 'NNS'),
#  ('sign', 'VBD'),
#  ('the', 'DT'),
#  ('deal', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('coming', 'JJ'),
#  ('weeks', 'NNS'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('hardly', 'RB'),
#  ('means', 'VBZ'),
#  ('an', 'DT'),
#  ('end', 'NN'),
#  ('to', 'TO'),
#  ('what', 'WP'),
#  ('are', 'VBP'),
#  ('sure', 'JJ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('difficult', 'JJ'),
#  ('negotiations', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('initial', 'JJ'),
#  ('agreement', 'NN'),
#  ('has', 'VBZ'),
#  ('marked', 'VBN'),
#  ('a', 'DT'),
#  ('pause', 'NN'),
#  ('in', 'IN'),
#  ('trade', 'NN'),
#  ('war', 'NN'),
#  ('escalation', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('has', 'VBZ'),
#  ('sharply', 'RB'),
#  ('boosted', 'VBN'),
#  ('markets', 'NNS'),
#  ('.', '.'),
#  ('Throughout', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('investors', 'NNS'),
#  ('fretted', 'VBD'),
#  ('a', 'DT'),
#  ('slowing', 'VBG'),
#  ('global', 'JJ'),
#  ('economy', 'NN'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('fears', 'NNS'),
#  ('stemmed', 'VBD'),
#  ('from', 'IN'),
#  ('disruptive', 'JJ'),
#  ('trade', 'NN'),
#  ('wars', 'NNS'),
#  ('and', 'CC'),
#  ('tariffs', 'NNS'),
#  (',', ','),
#  ('another', 'DT'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('U.K.', 'NNP'),
#  ("'s", 'POS'),
#  ('plans', 'NNS'),
#  ('to', 'TO'),
#  ('depart', 'VB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  (',', ','),
#  ('often', 'RB'),
#  ('called', 'VBD'),
#  ('Brexit', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('fears', 'NNS'),
#  ('of', 'IN'),
#  ('voters', 'NNS'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('shifting', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('far', 'RB'),
#  ('left', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('International', 'NNP'),
#  ('Monetary', 'NNP'),
#  ('Fund', 'NNP'),
#  ('has', 'VBZ'),
#  ('recently', 'RB'),
#  ('downgraded', 'VBN'),
#  ('its', 'PRP$'),
#  ('2019', 'CD'),
#  ('estimate', 'NN'),
#  ('for', 'IN'),
#  ('global', 'JJ'),
#  ('economic', 'JJ'),
#  ('growth', 'NN'),
#  ('to', 'TO'),
#  ('3', 'CD'),
#  ('%', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('lowest', 'JJS'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('financial', 'JJ'),
#  ('crisis', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('came', 'VBD'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('close', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('appeared', 'VBD'),
#  ('the', 'DT'),
#  ('U.K.', 'NNP'),
#  ('would', 'MD'),
#  ('more', 'RBR'),
#  ('likely', 'JJ'),
#  ('achieve', 'VBP'),
#  ('a', 'DT'),
#  ('negotiated', 'JJ'),
#  ('exit', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('EU', 'NNP'),
#  ('versus', 'NN'),
#  ('a', 'DT'),
#  ('hard', 'JJ'),
#  ('one', 'CD'),
#  ('and', 'CC'),
#  ('trade', 'VB'),
#  ('tensions', 'NNS'),
#  ('eased', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('phase', 'NN'),
#  ('one', 'CD'),
#  ('deal', 'NN'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('and', 'CC'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('some', 'DT'),
#  ('economists', 'NNS'),
#  ('are', 'VBP'),
#  ('expressing', 'VBG'),
#  ('hopes', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('global', 'JJ'),
#  ('economic', 'JJ'),
#  ('slowdown', 'NN'),
#  ('is', 'VBZ'),
#  ('bottoming', 'VBG'),
#  ('.', '.'),
#  ('Energy', 'NNP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('worst-performing', 'JJ'),
#  ('sector', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('S', 'NNP'),
#  ('&', 'CC'),
#  ('P', 'NNP'),
#  ('500', 'CD'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('oil', 'NN'),
#  ('is', 'VBZ'),
#  ('still', 'RB'),
#  ('the', 'DT'),
#  ('fuel', 'NN'),
#  ('of', 'IN'),
#  ('capitalism', 'NN'),
#  ('and', 'CC'),
#  ('depressed', 'VBD'),
#  ('prices', 'NNS'),
#  ('helped', 'VBD'),
#  ('bolster', 'VB'),
#  ('economic', 'JJ'),
#  ('activity', 'NN'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('globe', 'NN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ("'s", 'VBZ'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('recent', 'JJ'),
#  ('uptick', 'NN'),
#  ('in', 'IN'),
#  ('prices', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('West', 'NNP'),
#  ('Texas', 'NNP'),
#  ('Intermediate', 'NNP'),
#  ('crude', 'NN'),
#  ('futures', 'NNS'),
#  ('trading', 'VBG'),
#  ('for', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('$', '$'),
#  ('60', 'CD'),
#  ('a', 'DT'),
#  ('barrel', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('by', 'IN'),
#  ('historical', 'JJ'),
#  ('standards', 'NNS'),
#  (',', ','),
#  ('that', 'DT'),
#  ("'s", 'VBZ'),
#  ('hardly', 'RB'),
#  ('disruptive', 'JJ'),
#  ('.', '.'),
#  ('Despite', 'IN'),
#  ('sluggish', 'JJ'),
#  ('energy', 'NN'),
#  ('markets', 'NNS'),
#  (',', ','),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('highlights', 'NNS'),
#  ('of', 'IN'),
#  ('2019', 'CD'),
#  ('was', 'VBD'),
#  ('Saudi', 'NNP'),
#  ('Aramco', 'NNP'),
#  ("'s", 'POS'),
#  ('initial', 'JJ'),
#  ('public', 'JJ'),
#  ('stock', 'NN'),
#  ('offering', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('oil', 'NN'),
#  ('giant', 'NN'),
#  ('has', 'VBZ'),
#  ('reached', 'VBN'),
#  ('a', 'DT'),
#  ('valuation', 'NN'),
#  ('of', 'IN'),
#  ('$', '$'),
#  ('2', 'CD'),
#  ('trillion', 'CD'),
#  (',', ','),
#  ('becoming', 'VBG'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('valuable', 'JJ'),
#  ('company', 'NN'),
#  ('in', 'IN'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('August', 'NNP'),
#  (',', ','),
#  ('investors', 'NNS'),
#  ('began', 'VBD'),
#  ('parsing', 'VBG'),
#  ('the', 'DT'),
#  ('meaning', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('rare', 'JJ'),
#  ('market', 'NN'),
#  ('phenomena', 'NN'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('inverted', 'JJ'),
#  ('yield', 'NN'),
#  ('curve', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('occurs', 'VBZ'),
#  ('when', 'WRB'),
#  ('short-term', 'JJ'),
#  ('interest', 'NN'),
#  ('rates', 'NNS'),
#  ('are', 'VBP'),
#  ('higher', 'JJR'),
#  ('than', 'IN'),
#  ('longer', 'JJR'),
#  ('term', 'NN'),
#  ('rates', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('often', 'RB'),
#  ('a', 'DT'),
#  ('bad', 'JJ'),
#  ('sign', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('economy', 'NN'),
#  ('.', '.'),
#  ('Historically', 'NNP'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('yield', 'NN'),
#  ('curve', 'NN'),
#  ('inverts', 'NNS'),
#  (',', ','),
#  ('a', 'DT'),
#  ('recession', 'NN'),
#  ('follows', 'VBZ'),
#  ('within', 'IN'),
#  ('one', 'CD'),
#  ('or', 'CC'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('Recession', 'NNP'),
#  ('fears', 'NNS'),
#  ('indeed', 'RB'),
#  ('swelled', 'VBD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('yield', 'NN'),
#  ('curve', 'NN'),
#  ('inverted', 'VBN'),
#  ('.', '.'),
#  ('Investors', 'NNS'),
#  ('also', 'RB'),
#  ('began', 'VBD'),
#  ('to', 'TO'),
#  ('considered', 'VB'),
#  ('a', 'DT'),
#  ('$', '$'),
#  ('17', 'CD'),
#  ('trillion', 'CD'),
#  ('pile', 'NN'),
#  ('of', 'IN'),
#  ('negative-yielding', 'JJ'),
#  ('debt', 'NN'),
#  ('from', 'IN'),
#  ('sovereign', 'JJ'),
#  ('nations', 'NNS'),
#  (',', ','),
#  ('mostly', 'RB'),
#  ('in', 'IN'),
#  ('Europe', 'NNP'),
#  ('.', '.'),
#  ...]

# %%
# create a tag pattern to chunk
# NP (noun phrase) = DT (One optional Determiner) + JJ (any number of adjs) + NN (one Noun).
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# chunking with Regular Expressions
chunking_noun = nltk.RegexpParser(pattern).parse(preprocess)
#print(chunking_noun)

# print Noun Phrases
for chunk in chunking_noun:
  if hasattr(chunk, 'label'):
    print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# NP a year
# NP a bear market
# NP a gain
# NP %
# NP a performance
# NP %
# NP gain
# NP %
# NP return
# NP a gain
# NP %
# NP money
# NP position
# NP %
# NP a year
# NP a global economic slowdown
# NP disruptive trade
# NP policy
# NP The year
# NP an unforeseen boom
# NP the tech
# NP sector
# NP the major stock
# NP the key
# NP the market
# NP success
# NP a low base
# NP A steep sell-off
# NP %
# NP a bear market
# NP %
# NP decline
# NP closing
# NP peak
# NP a loss
# NP %
# NP trading
# NP perspective
# NP %
# NP the average return
# NP %
# NP the stock
# NP market
# NP a dramatic policy
# NP shift
# NP hike
# NP key rate
# NP percent
# NP a different story
# NP a change
# NP heart
# NP interest
# NP a quest
# NP yield
# NP money
# NP key rate
# NP a range
# NP %
# NP %
# NP clarity
# NP top
# NP the central bank
# NP insurance
# NP rate
# NP global economy
# NP global economic growth
# NP trade
# NP the re-crafting
# NP trade
# NP war
# NP the financial news
# NP the year
# NP tweet
# NP the course
# NP the year
# NP the trade
# NP war
# NP the stock
# NP market
# NP the year
# NP a close
# NP replacement
# NP administration
# NP a phase
# NP trade
# NP agreement
# NP the deal
# NP an end
# NP the initial agreement
# NP a pause
# NP trade
# NP war
# NP escalation
# NP global economy
# NP disruptive trade
# NP the world
# NP left
# NP estimate
# NP global economic growth
# NP %
# NP the financial crisis
# NP the year
# NP a close
# NP a negotiated exit
# NP versus
# NP the phase
# NP deal
# NP the global economic slowdown
# NP the worst-performing sector
# NP oil
# NP the fuel
# NP capitalism
# NP economic activity
# NP the globe
# NP a recent uptick
# NP crude
# NP a barrel
# NP sluggish energy
# NP initial public stock
# NP offering
# NP The oil
# NP giant
# NP a valuation
# NP valuable company
# NP history
# NP the meaning
# NP a rare market
# NP phenomena
# NP the inverted yield
# NP curve
# NP short-term interest
# NP term
# NP a bad sign
# NP the economy
# NP the yield
# NP curve
# NP a recession
# NP the yield
# NP curve
# NP pile
# NP negative-yielding debt
# NP negative yielding
# NP bond
# NP a yield
# NP maturity
# NP the year
# NP bond
# NP the yield
# NP curve
# NP optimism
# NP economy
# NP benchmark interest
# NP rate
# NP current level
# NP this year
# NP The spread
# NP level
# NP the global growth
# NP scare
# NP rate
# NP manufacturing
# NP activity
# NP the fourth straight month
# NP The manufacturing
# NP contraction
# NP a key part
# NP the economic slowdown
# NP the other hand
# NP non-manufacturing index
# NP the service
# NP sector
# NP strong consumer
# NP spending
# NP low unemployment
# NP rate
# NP percent
# NP %
# NP %
# NP %
# NP a market
# NP capitalization
# NP a cap-weighted index
# NP an outsized influence
# NP parent
# NP company
# NP Semiconductor
# NP the index
# NP the end
# NP a confluence
# NP technology
# NP easy money
# NP a wall
# NP worry
# NP any other year
# NP a confidential news
# NP tip
# NP inbox
# NP inbox
# NP A Division
# NP a real-time snapshot

# %% [markdown]
# **IOB tags**: Each token is tagged with one of three special chunk tags, I (inside), O (outside), or B (begin).
#
# A token is tagged as B if it marks the beginning of a chunk.
#
# Tokens within the chunk are tagged I.
#
# All other tokens are tagged O.

# %%
# Convert a tree to the CoNLL IOB tag
iob_tagged = tree2conlltags(chunking_noun)
for child in iob_tagged:             
    print (child)
# Out:
# ('It', 'PRP', 'O')
# ('was', 'VBD', 'O')
# ('a', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('that', 'WDT', 'O')
# ('began', 'VBD', 'O')
# ('with', 'IN', 'O')
# ('investors', 'NNS', 'O')
# ('courting', 'VBG', 'O')
# ('a', 'DT', 'B-NP')
# ('bear', 'JJ', 'I-NP')
# ('market', 'NN', 'I-NP')
# ('and', 'CC', 'O')
# ('ended', 'VBD', 'O')
# ('with', 'IN', 'O')
# ('the', 'DT', 'O')
# ('biggest', 'JJS', 'O')
# ('gains', 'NNS', 'O')
# ('from', 'IN', 'O')
# ('stocks', 'NNS', 'O')
# ('since', 'IN', 'O')
# ('2013', 'CD', 'O')
# ('.', '.', 'O')
# ('Twelve', 'CD', 'O')
# ('months', 'NNS', 'O')
# ('ago', 'RB', 'O')
# (',', ',', 'O')
# ('few', 'JJ', 'O')
# ('could', 'MD', 'O')
# ('have', 'VB', 'O')
# ('imagined', 'VBN', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ('delivering', 'VBG', 'O')
# ('a', 'DT', 'B-NP')
# ('gain', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('more', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('28', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# ('.', '.', 'O')
# ('It', 'PRP', 'O')
# ('was', 'VBD', 'O')
# ('a', 'DT', 'B-NP')
# ('performance', 'NN', 'I-NP')
# ('that', 'WDT', 'O')
# ('flirted', 'VBD', 'O')
# ('with', 'IN', 'O')
# ('the', 'DT', 'O')
# ('31', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('gain', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('1997', 'CD', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('one', 'CD', 'O')
# ('that', 'WDT', 'O')
# ('came', 'VBD', 'O')
# ('very', 'RB', 'O')
# ('close', 'RB', 'O')
# ('to', 'TO', 'O')
# ('topping', 'VBG', 'O')
# ('the', 'DT', 'O')
# ('29.6', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('return', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('2013', 'CD', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('tech-heavy', 'JJ', 'O')
# ('Nasdaq', 'NNP', 'O')
# ('did', 'VBD', 'O')
# ('even', 'RB', 'O')
# ('better', 'RBR', 'O')
# (',', ',', 'O')
# ('posting', 'VBG', 'O')
# ('a', 'DT', 'B-NP')
# ('gain', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('35', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('as', 'IN', 'O')
# ('money', 'NN', 'B-NP')
# ('flowed', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('the', 'DT', 'O')
# ('tech', 'JJ', 'O')
# ('giants', 'NNS', 'O')
# (',', ',', 'O')
# ('cementing', 'VBG', 'O')
# ('Apple', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('Microsoft', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('position', 'NN', 'B-NP')
# ('as', 'IN', 'O')
# ('trillion-dollar', 'JJ', 'O')
# ('companies', 'NNS', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('Dow', 'NNP', 'O')
# ('Jones', 'NNP', 'O')
# ('Industrial', 'NNP', 'O')
# ('Average', 'NNP', 'O')
# ('was', 'VBD', 'O')
# ('up', 'RB', 'O')
# ('22', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('It', 'PRP', 'O')
# ('was', 'VBD', 'O')
# ('a', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('filled', 'VBN', 'O')
# ('with', 'IN', 'O')
# ('fears', 'NNS', 'O')
# ('that', 'WDT', 'O')
# ('were', 'VBD', 'O')
# ('never', 'RB', 'O')
# ('realized', 'VBN', 'O')
# (':', ':', 'O')
# ('a', 'DT', 'B-NP')
# ('global', 'JJ', 'I-NP')
# ('economic', 'JJ', 'I-NP')
# ('slowdown', 'NN', 'I-NP')
# (',', ',', 'O')
# ('disruptive', 'JJ', 'B-NP')
# ('trade', 'NN', 'I-NP')
# ('wars', 'NNS', 'O')
# ('and', 'CC', 'O')
# ('potential', 'JJ', 'O')
# ('missteps', 'NNS', 'O')
# ('from', 'IN', 'O')
# ('Federal', 'NNP', 'O')
# ('Reserve', 'NNP', 'O')
# ('policy', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('also', 'RB', 'O')
# ('revealed', 'VBD', 'O')
# ('an', 'DT', 'B-NP')
# ('unforeseen', 'JJ', 'I-NP')
# ('boom', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('tech', 'NN', 'I-NP')
# ('sector', 'NN', 'B-NP')
# ('that', 'WDT', 'O')
# ('drove', 'VBD', 'O')
# ('the', 'DT', 'B-NP')
# ('major', 'JJ', 'I-NP')
# ('stock', 'NN', 'I-NP')
# ('indexes', 'NNS', 'O')
# ('ever', 'RB', 'O')
# ('higher', 'JJR', 'O')
# ('.', '.', 'O')
# ('One', 'CD', 'O')
# ('of', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('key', 'NN', 'I-NP')
# ("'s", 'POS', 'O')
# ('to', 'TO', 'O')
# ('the', 'DT', 'B-NP')
# ('market', 'NN', 'I-NP')
# ("'s", 'POS', 'O')
# ('2019', 'CD', 'O')
# ('success', 'NN', 'B-NP')
# ('was', 'VBD', 'O')
# ('starting', 'VBG', 'O')
# ('from', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('low', 'JJ', 'I-NP')
# ('base', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('A', 'DT', 'B-NP')
# ('steep', 'JJ', 'I-NP')
# ('sell-off', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('December', 'NNP', 'O')
# ('2018', 'CD', 'O')
# ('left', 'VBD', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ('just', 'RB', 'O')
# ('0.2', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('from', 'IN', 'O')
# ('officially', 'RB', 'O')
# ('hitting', 'VBG', 'O')
# ('a', 'DT', 'B-NP')
# ('bear', 'JJ', 'I-NP')
# ('market', 'NN', 'I-NP')
# (',', ',', 'O')
# ('defined', 'VBD', 'O')
# ('as', 'IN', 'O')
# ('a', 'DT', 'O')
# ('20', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('decline', 'NN', 'B-NP')
# ('from', 'IN', 'O')
# ('its', 'PRP$', 'O')
# ('closing', 'NN', 'B-NP')
# ('peak', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ('ended', 'VBD', 'O')
# ('2018', 'CD', 'O')
# ('with', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('loss', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('more', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('6', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# (',', ',', 'O')
# ('closing', 'VBG', 'O')
# ('at', 'IN', 'O')
# ('2,485.74', 'CD', 'O')
# ('on', 'IN', 'O')
# ('Dec.', 'NNP', 'O')
# ('31', 'CD', 'O')
# (',', ',', 'O')
# ('2018', 'CD', 'O')
# ('.', '.', 'O')
# ('In', 'IN', 'O')
# ('the', 'DT', 'O')
# ('final', 'JJ', 'O')
# ('hours', 'NNS', 'O')
# ('of', 'IN', 'O')
# ('trading', 'NN', 'B-NP')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# (',', ',', 'O')
# ('it', 'PRP', 'O')
# ("'s", 'VBZ', 'O')
# ('trading', 'VBG', 'O')
# ('around', 'RB', 'O')
# ('3,220', 'CD', 'O')
# ('.', '.', 'O')
# ('For', 'IN', 'O')
# ('perspective', 'NN', 'B-NP')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('is', 'VBZ', 'O')
# ('finishing', 'JJ', 'O')
# ('2019', 'CD', 'O')
# ('about', 'IN', 'O')
# ('10', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('above', 'IN', 'O')
# ('2018', 'CD', 'O')
# ("'s", 'POS', 'O')
# ('high', 'JJ', 'O')
# ('of', 'IN', 'O')
# ('roughly', 'RB', 'O')
# ('2,900', 'CD', 'O')
# (',', ',', 'O')
# ('which', 'WDT', 'O')
# ('is', 'VBZ', 'O')
# ('close', 'RB', 'O')
# ('to', 'TO', 'O')
# ('the', 'DT', 'B-NP')
# ('average', 'JJ', 'I-NP')
# ('return', 'NN', 'I-NP')
# ('for', 'IN', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ('over', 'IN', 'O')
# ('90', 'CD', 'O')
# ('years', 'NNS', 'O')
# ('of', 'IN', 'O')
# ('9.8', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('Much', 'JJ', 'O')
# ('of', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('stock', 'NN', 'I-NP')
# ('market', 'NN', 'B-NP')
# ("'s", 'POS', 'O')
# ('gains', 'NNS', 'O')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# ('can', 'MD', 'O')
# ('be', 'VB', 'O')
# ('attributed', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('a', 'DT', 'B-NP')
# ('dramatic', 'JJ', 'I-NP')
# ('policy', 'NN', 'I-NP')
# ('shift', 'NN', 'B-NP')
# ('at', 'IN', 'O')
# ('the', 'DT', 'O')
# ('Federal', 'NNP', 'O')
# ('Reserve', 'NNP', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ('raised', 'VBD', 'O')
# ('rates', 'NNS', 'O')
# ('four', 'CD', 'O')
# ('times', 'NNS', 'O')
# ('in', 'IN', 'O')
# ('2018', 'CD', 'O')
# (',', ',', 'O')
# ('including', 'VBG', 'O')
# ('a', 'DT', 'O')
# ('December', 'NNP', 'O')
# ('2018', 'CD', 'O')
# ('hike', 'NN', 'B-NP')
# ('that', 'WDT', 'O')
# ('took', 'VBD', 'O')
# ('its', 'PRP$', 'O')
# ('key', 'JJ', 'B-NP')
# ('rate', 'NN', 'I-NP')
# ('to', 'TO', 'O')
# ('2.5', 'CD', 'O')
# ('percent', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('It', 'PRP', 'O')
# ('was', 'VBD', 'O')
# ('a', 'DT', 'B-NP')
# ('different', 'JJ', 'I-NP')
# ('story', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# (',', ',', 'O')
# ('when', 'WRB', 'O')
# ('after', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('change', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('heart', 'NN', 'B-NP')
# ('the', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ('lowered', 'VBD', 'O')
# ('rates', 'NNS', 'O')
# ('three', 'CD', 'O')
# ('times', 'NNS', 'O')
# ('.', '.', 'O')
# ('Falling', 'VBG', 'O')
# ('interest', 'NN', 'B-NP')
# ('rates', 'NNS', 'O')
# ('sent', 'VBD', 'O')
# ('investors', 'NNS', 'O')
# ('on', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('quest', 'NN', 'I-NP')
# ('for', 'IN', 'O')
# ('yield', 'NN', 'B-NP')
# (',', ',', 'O')
# ('forcing', 'VBG', 'O')
# ('more', 'JJR', 'O')
# ('money', 'NN', 'B-NP')
# ('into', 'IN', 'O')
# ('stocks', 'NNS', 'O')
# ('expected', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('appreciate', 'VB', 'O')
# (',', ',', 'O')
# ('pay', 'VB', 'O')
# ('dividends', 'NNS', 'O')
# ('or', 'CC', 'O')
# ('both', 'DT', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('key', 'JJ', 'B-NP')
# ('rate', 'NN', 'I-NP')
# ('is', 'VBZ', 'O')
# ('now', 'RB', 'O')
# ('back', 'RB', 'O')
# ('to', 'TO', 'O')
# ('a', 'DT', 'B-NP')
# ('range', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('1.50', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('to', 'TO', 'O')
# ('1.75', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('Additionally', 'RB', 'O')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ('has', 'VBZ', 'O')
# ('said', 'VBD', 'O')
# ('it', 'PRP', 'O')
# ('expects', 'VBZ', 'O')
# ('to', 'TO', 'O')
# ('leave', 'VB', 'O')
# ('rates', 'NNS', 'O')
# ('unchanged', 'JJ', 'O')
# ('for', 'IN', 'O')
# ('2020', 'CD', 'O')
# (',', ',', 'O')
# ('giving', 'VBG', 'O')
# ('investors', 'NNS', 'O')
# ('clarity', 'NN', 'B-NP')
# ('on', 'IN', 'O')
# ('top', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('what', 'WP', 'O')
# ('remain', 'VBP', 'O')
# ('historically', 'RB', 'O')
# ('low', 'JJ', 'O')
# ('rates', 'NNS', 'O')
# ('.', '.', 'O')
# ('Fed', 'NNP', 'O')
# ('Chairman', 'NNP', 'O')
# ('Jerome', 'NNP', 'O')
# ('Powell', 'NNP', 'O')
# ('described', 'VBD', 'O')
# ('the', 'DT', 'B-NP')
# ('central', 'JJ', 'I-NP')
# ('bank', 'NN', 'I-NP')
# ("'s", 'POS', 'O')
# ('moves', 'NNS', 'O')
# ('as', 'IN', 'O')
# ('``', '``', 'O')
# ('insurance', 'NN', 'B-NP')
# ("''", "''", 'O')
# ('rate', 'NN', 'B-NP')
# ('cuts', 'NNS', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ('wanted', 'VBD', 'O')
# ('to', 'TO', 'O')
# ('ensure', 'VB', 'O')
# ('a', 'DT', 'O')
# ('slowing', 'VBG', 'O')
# ('global', 'JJ', 'B-NP')
# ('economy', 'NN', 'I-NP')
# ('did', 'VBD', 'O')
# ("n't", 'RB', 'O')
# ('drag', 'VB', 'O')
# ('down', 'RP', 'O')
# ('the', 'DT', 'O')
# ('U.S.', 'NNP', 'O')
# ('One', 'CD', 'O')
# ('of', 'IN', 'O')
# ('the', 'DT', 'O')
# ('biggest', 'JJS', 'O')
# ('uncertainties', 'NNS', 'O')
# ('for', 'IN', 'O')
# ('global', 'JJ', 'B-NP')
# ('economic', 'JJ', 'I-NP')
# ('growth', 'NN', 'I-NP')
# ('was', 'VBD', 'O')
# ('President', 'NNP', 'O')
# ('Donald', 'NNP', 'O')
# ('Trump', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('trade', 'NN', 'B-NP')
# ('negotiations', 'NNS', 'O')
# ('with', 'IN', 'O')
# ('China', 'NNP', 'O')
# ('as', 'RB', 'O')
# ('well', 'RB', 'O')
# ('as', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('re-crafting', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('the', 'DT', 'O')
# ('North', 'JJ', 'O')
# ('American', 'JJ', 'O')
# ('Free', 'NNP', 'O')
# ('Trade', 'NNP', 'O')
# ('Agreement', 'NNP', 'O')
# ('with', 'IN', 'O')
# ('Canada', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('Mexico', 'NNP', 'O')
# ('.', '.', 'O')
# ('Indeed', 'RB', 'O')
# (',', ',', 'O')
# ('trade', 'NN', 'B-NP')
# ('war', 'NN', 'B-NP')
# ('headlines', 'NNS', 'O')
# ('dominated', 'VBD', 'O')
# ('the', 'DT', 'B-NP')
# ('financial', 'JJ', 'I-NP')
# ('news', 'NN', 'I-NP')
# ('throughout', 'IN', 'O')
# ('most', 'JJS', 'O')
# ('of', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('Trump', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('tariffs', 'NNS', 'O')
# ('and', 'CC', 'O')
# ('threats', 'NNS', 'O')
# ('of', 'IN', 'O')
# ('more', 'JJR', 'O')
# ('tariffs', 'NNS', 'O')
# ('often', 'RB', 'O')
# ('sent', 'VBD', 'O')
# ('indexes', 'NNS', 'O')
# ('frightfully', 'RB', 'O')
# ('lower', 'JJR', 'O')
# ('.', '.', 'O')
# ('Then', 'RB', 'O')
# ('his', 'PRP$', 'O')
# ('pronouncements', 'NNS', 'O')
# (',', ',', 'O')
# ('usually', 'RB', 'O')
# ('by', 'IN', 'O')
# ('tweet', 'NN', 'B-NP')
# (',', ',', 'O')
# ('that', 'IN', 'O')
# ('deals', 'NNS', 'O')
# ('were', 'VBD', 'O')
# ('coming', 'VBG', 'O')
# ('together', 'RB', 'O')
# (',', ',', 'O')
# ('would', 'MD', 'O')
# ('send', 'VB', 'O')
# ('markets', 'NNS', 'O')
# ('back', 'RB', 'O')
# ('even', 'RB', 'O')
# ('higher', 'JJR', 'O')
# ('.', '.', 'O')
# ('Over', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('course', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# (',', ',', 'O')
# ('however', 'RB', 'O')
# (',', ',', 'O')
# ('the', 'DT', 'B-NP')
# ('trade', 'NN', 'I-NP')
# ('war', 'NN', 'B-NP')
# ('had', 'VBD', 'O')
# ('only', 'RB', 'O')
# ('transient', 'JJ', 'O')
# ('effects', 'NNS', 'O')
# ('on', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('stock', 'NN', 'I-NP')
# ('market', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('As', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('came', 'VBD', 'O')
# ('to', 'TO', 'O')
# ('a', 'DT', 'B-NP')
# ('close', 'NN', 'I-NP')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('House', 'NNP', 'O')
# ('passed', 'VBD', 'O')
# ('the', 'DT', 'O')
# ('United', 'NNP', 'O')
# ('States-Mexico-Canada', 'NNP', 'O')
# ('Agreement', 'NNP', 'O')
# (',', ',', 'O')
# ('which', 'WDT', 'O')
# ('is', 'VBZ', 'O')
# ('Trump', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('replacement', 'NN', 'B-NP')
# ('for', 'IN', 'O')
# ('NAFTA', 'NNP', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('the', 'DT', 'O')
# ('Senate', 'NNP', 'O')
# ('is', 'VBZ', 'O')
# ('expected', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('pass', 'VB', 'O')
# ('it', 'PRP', 'O')
# ('soon', 'RB', 'O')
# ('.', '.', 'O')
# ('Also', 'RB', 'O')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('Trump', 'NNP', 'O')
# ('administration', 'NN', 'B-NP')
# ('has', 'VBZ', 'O')
# ('come', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('a', 'DT', 'B-NP')
# ('phase', 'NN', 'I-NP')
# ('one', 'CD', 'O')
# ('trade', 'NN', 'B-NP')
# ('agreement', 'NN', 'B-NP')
# ('with', 'IN', 'O')
# ('China', 'NNP', 'O')
# ('.', '.', 'O')
# ('When', 'WRB', 'O')
# ('U.S.', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('China', 'NNP', 'O')
# ('officials', 'NNS', 'O')
# ('sign', 'VBD', 'O')
# ('the', 'DT', 'B-NP')
# ('deal', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('the', 'DT', 'O')
# ('coming', 'JJ', 'O')
# ('weeks', 'NNS', 'O')
# (',', ',', 'O')
# ('it', 'PRP', 'O')
# ('hardly', 'RB', 'O')
# ('means', 'VBZ', 'O')
# ('an', 'DT', 'B-NP')
# ('end', 'NN', 'I-NP')
# ('to', 'TO', 'O')
# ('what', 'WP', 'O')
# ('are', 'VBP', 'O')
# ('sure', 'JJ', 'O')
# ('to', 'TO', 'O')
# ('be', 'VB', 'O')
# ('difficult', 'JJ', 'O')
# ('negotiations', 'NNS', 'O')
# (',', ',', 'O')
# ('but', 'CC', 'O')
# ('the', 'DT', 'B-NP')
# ('initial', 'JJ', 'I-NP')
# ('agreement', 'NN', 'I-NP')
# ('has', 'VBZ', 'O')
# ('marked', 'VBN', 'O')
# ('a', 'DT', 'B-NP')
# ('pause', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('trade', 'NN', 'B-NP')
# ('war', 'NN', 'B-NP')
# ('escalation', 'NN', 'B-NP')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('that', 'DT', 'O')
# ('has', 'VBZ', 'O')
# ('sharply', 'RB', 'O')
# ('boosted', 'VBN', 'O')
# ('markets', 'NNS', 'O')
# ('.', '.', 'O')
# ('Throughout', 'IN', 'O')
# ('2019', 'CD', 'O')
# (',', ',', 'O')
# ('investors', 'NNS', 'O')
# ('fretted', 'VBD', 'O')
# ('a', 'DT', 'O')
# ('slowing', 'VBG', 'O')
# ('global', 'JJ', 'B-NP')
# ('economy', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('Some', 'DT', 'O')
# ('of', 'IN', 'O')
# ('those', 'DT', 'O')
# ('fears', 'NNS', 'O')
# ('stemmed', 'VBD', 'O')
# ('from', 'IN', 'O')
# ('disruptive', 'JJ', 'B-NP')
# ('trade', 'NN', 'I-NP')
# ('wars', 'NNS', 'O')
# ('and', 'CC', 'O')
# ('tariffs', 'NNS', 'O')
# (',', ',', 'O')
# ('another', 'DT', 'O')
# ('was', 'VBD', 'O')
# ('the', 'DT', 'O')
# ('U.K.', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('plans', 'NNS', 'O')
# ('to', 'TO', 'O')
# ('depart', 'VB', 'O')
# ('from', 'IN', 'O')
# ('the', 'DT', 'O')
# ('European', 'NNP', 'O')
# ('Union', 'NNP', 'O')
# (',', ',', 'O')
# ('often', 'RB', 'O')
# ('called', 'VBD', 'O')
# ('Brexit', 'NNP', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('fears', 'NNS', 'O')
# ('of', 'IN', 'O')
# ('voters', 'NNS', 'O')
# ('around', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('world', 'NN', 'I-NP')
# ('shifting', 'VBG', 'O')
# ('to', 'TO', 'O')
# ('the', 'DT', 'O')
# ('far', 'RB', 'O')
# ('left', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('International', 'NNP', 'O')
# ('Monetary', 'NNP', 'O')
# ('Fund', 'NNP', 'O')
# ('has', 'VBZ', 'O')
# ('recently', 'RB', 'O')
# ('downgraded', 'VBN', 'O')
# ('its', 'PRP$', 'O')
# ('2019', 'CD', 'O')
# ('estimate', 'NN', 'B-NP')
# ('for', 'IN', 'O')
# ('global', 'JJ', 'B-NP')
# ('economic', 'JJ', 'I-NP')
# ('growth', 'NN', 'I-NP')
# ('to', 'TO', 'O')
# ('3', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('lowest', 'JJS', 'O')
# ('since', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('financial', 'JJ', 'I-NP')
# ('crisis', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('But', 'CC', 'O')
# ('as', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('came', 'VBD', 'O')
# ('to', 'TO', 'O')
# ('a', 'DT', 'B-NP')
# ('close', 'NN', 'I-NP')
# (',', ',', 'O')
# ('it', 'PRP', 'O')
# ('appeared', 'VBD', 'O')
# ('the', 'DT', 'O')
# ('U.K.', 'NNP', 'O')
# ('would', 'MD', 'O')
# ('more', 'RBR', 'O')
# ('likely', 'JJ', 'O')
# ('achieve', 'VBP', 'O')
# ('a', 'DT', 'B-NP')
# ('negotiated', 'JJ', 'I-NP')
# ('exit', 'NN', 'I-NP')
# ('from', 'IN', 'O')
# ('the', 'DT', 'O')
# ('EU', 'NNP', 'O')
# ('versus', 'NN', 'B-NP')
# ('a', 'DT', 'O')
# ('hard', 'JJ', 'O')
# ('one', 'CD', 'O')
# ('and', 'CC', 'O')
# ('trade', 'VB', 'O')
# ('tensions', 'NNS', 'O')
# ('eased', 'VBN', 'O')
# ('with', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('phase', 'NN', 'I-NP')
# ('one', 'CD', 'O')
# ('deal', 'NN', 'B-NP')
# ('between', 'IN', 'O')
# ('the', 'DT', 'O')
# ('U.S.', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('China', 'NNP', 'O')
# ('.', '.', 'O')
# ('And', 'CC', 'O')
# ('some', 'DT', 'O')
# ('economists', 'NNS', 'O')
# ('are', 'VBP', 'O')
# ('expressing', 'VBG', 'O')
# ('hopes', 'NNS', 'O')
# ('that', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('global', 'JJ', 'I-NP')
# ('economic', 'JJ', 'I-NP')
# ('slowdown', 'NN', 'I-NP')
# ('is', 'VBZ', 'O')
# ('bottoming', 'VBG', 'O')
# ('.', '.', 'O')
# ('Energy', 'NNP', 'O')
# ('was', 'VBD', 'O')
# ('the', 'DT', 'B-NP')
# ('worst-performing', 'JJ', 'I-NP')
# ('sector', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# ('.', '.', 'O')
# ('But', 'CC', 'O')
# ('oil', 'NN', 'B-NP')
# ('is', 'VBZ', 'O')
# ('still', 'RB', 'O')
# ('the', 'DT', 'B-NP')
# ('fuel', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('capitalism', 'NN', 'B-NP')
# ('and', 'CC', 'O')
# ('depressed', 'VBD', 'O')
# ('prices', 'NNS', 'O')
# ('helped', 'VBD', 'O')
# ('bolster', 'VB', 'O')
# ('economic', 'JJ', 'B-NP')
# ('activity', 'NN', 'I-NP')
# ('around', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('globe', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('There', 'EX', 'O')
# ("'s", 'VBZ', 'O')
# ('been', 'VBN', 'O')
# ('a', 'DT', 'B-NP')
# ('recent', 'JJ', 'I-NP')
# ('uptick', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('prices', 'NNS', 'O')
# (',', ',', 'O')
# ('with', 'IN', 'O')
# ('West', 'NNP', 'O')
# ('Texas', 'NNP', 'O')
# ('Intermediate', 'NNP', 'O')
# ('crude', 'NN', 'B-NP')
# ('futures', 'NNS', 'O')
# ('trading', 'VBG', 'O')
# ('for', 'IN', 'O')
# ('more', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('$', '$', 'O')
# ('60', 'CD', 'O')
# ('a', 'DT', 'B-NP')
# ('barrel', 'NN', 'I-NP')
# (',', ',', 'O')
# ('but', 'CC', 'O')
# ('by', 'IN', 'O')
# ('historical', 'JJ', 'O')
# ('standards', 'NNS', 'O')
# (',', ',', 'O')
# ('that', 'DT', 'O')
# ("'s", 'VBZ', 'O')
# ('hardly', 'RB', 'O')
# ('disruptive', 'JJ', 'O')
# ('.', '.', 'O')
# ('Despite', 'IN', 'O')
# ('sluggish', 'JJ', 'B-NP')
# ('energy', 'NN', 'I-NP')
# ('markets', 'NNS', 'O')
# (',', ',', 'O')
# ('one', 'CD', 'O')
# ('of', 'IN', 'O')
# ('the', 'DT', 'O')
# ('highlights', 'NNS', 'O')
# ('of', 'IN', 'O')
# ('2019', 'CD', 'O')
# ('was', 'VBD', 'O')
# ('Saudi', 'NNP', 'O')
# ('Aramco', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('initial', 'JJ', 'B-NP')
# ('public', 'JJ', 'I-NP')
# ('stock', 'NN', 'I-NP')
# ('offering', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'B-NP')
# ('oil', 'NN', 'I-NP')
# ('giant', 'NN', 'B-NP')
# ('has', 'VBZ', 'O')
# ('reached', 'VBN', 'O')
# ('a', 'DT', 'B-NP')
# ('valuation', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('$', '$', 'O')
# ('2', 'CD', 'O')
# ('trillion', 'CD', 'O')
# (',', ',', 'O')
# ('becoming', 'VBG', 'O')
# ('the', 'DT', 'O')
# ('most', 'RBS', 'O')
# ('valuable', 'JJ', 'B-NP')
# ('company', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('history', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('In', 'IN', 'O')
# ('August', 'NNP', 'O')
# (',', ',', 'O')
# ('investors', 'NNS', 'O')
# ('began', 'VBD', 'O')
# ('parsing', 'VBG', 'O')
# ('the', 'DT', 'B-NP')
# ('meaning', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('rare', 'JJ', 'I-NP')
# ('market', 'NN', 'I-NP')
# ('phenomena', 'NN', 'B-NP')
# ('known', 'VBN', 'O')
# ('as', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('inverted', 'JJ', 'I-NP')
# ('yield', 'NN', 'I-NP')
# ('curve', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('This', 'DT', 'O')
# ('occurs', 'VBZ', 'O')
# ('when', 'WRB', 'O')
# ('short-term', 'JJ', 'B-NP')
# ('interest', 'NN', 'I-NP')
# ('rates', 'NNS', 'O')
# ('are', 'VBP', 'O')
# ('higher', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('longer', 'JJR', 'O')
# ('term', 'NN', 'B-NP')
# ('rates', 'NNS', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('it', 'PRP', 'O')
# ("'s", 'VBZ', 'O')
# ('often', 'RB', 'O')
# ('a', 'DT', 'B-NP')
# ('bad', 'JJ', 'I-NP')
# ('sign', 'NN', 'I-NP')
# ('for', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('economy', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('Historically', 'NNP', 'O')
# (',', ',', 'O')
# ('when', 'WRB', 'O')
# ('the', 'DT', 'B-NP')
# ('yield', 'NN', 'I-NP')
# ('curve', 'NN', 'B-NP')
# ('inverts', 'NNS', 'O')
# (',', ',', 'O')
# ('a', 'DT', 'B-NP')
# ('recession', 'NN', 'I-NP')
# ('follows', 'VBZ', 'O')
# ('within', 'IN', 'O')
# ('one', 'CD', 'O')
# ('or', 'CC', 'O')
# ('two', 'CD', 'O')
# ('years', 'NNS', 'O')
# ('.', '.', 'O')
# ('Recession', 'NNP', 'O')
# ('fears', 'NNS', 'O')
# ('indeed', 'RB', 'O')
# ('swelled', 'VBD', 'O')
# ('as', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('yield', 'NN', 'I-NP')
# ('curve', 'NN', 'B-NP')
# ('inverted', 'VBN', 'O')
# ('.', '.', 'O')
# ('Investors', 'NNS', 'O')
# ('also', 'RB', 'O')
# ('began', 'VBD', 'O')
# ('to', 'TO', 'O')
# ('considered', 'VB', 'O')
# ('a', 'DT', 'O')
# ('$', '$', 'O')
# ('17', 'CD', 'O')
# ('trillion', 'CD', 'O')
# ('pile', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('negative-yielding', 'JJ', 'B-NP')
# ('debt', 'NN', 'I-NP')
# ('from', 'IN', 'O')
# ('sovereign', 'JJ', 'O')
# ('nations', 'NNS', 'O')
# (',', ',', 'O')
# ('mostly', 'RB', 'O')
# ('in', 'IN', 'O')
# ('Europe', 'NNP', 'O')
# ('.', '.', 'O')
# ('A', 'NNP', 'O')
# ('negative', 'JJ', 'B-NP')
# ('yielding', 'NN', 'I-NP')
# ('bond', 'NN', 'B-NP')
# ('would', 'MD', 'O')
# ('have', 'VB', 'O')
# ('a', 'DT', 'B-NP')
# ('yield', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('less', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('zero', 'CD', 'O')
# ('if', 'IN', 'O')
# ('held', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('maturity', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('As', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('progressed', 'VBD', 'O')
# (',', ',', 'O')
# ('bond', 'NN', 'B-NP')
# ('markets', 'NNS', 'O')
# ('stabilized', 'VBD', 'O')
# ('and', 'CC', 'O')
# ('the', 'DT', 'B-NP')
# ('yield', 'NN', 'I-NP')
# ('curve', 'NN', 'B-NP')
# ('that', 'IN', 'O')
# ('investors', 'NNS', 'O')
# ('had', 'VBD', 'O')
# ('feared', 'VBN', 'O')
# ('finally', 'RB', 'O')
# ('steepened', 'VBN', 'O')
# ('on', 'IN', 'O')
# ('optimism', 'NN', 'B-NP')
# ('that', 'IN', 'O')
# ('the', 'DT', 'O')
# ('U.S.', 'NNP', 'O')
# ('economy', 'NN', 'B-NP')
# ('would', 'MD', 'O')
# ("n't", 'RB', 'O')
# ('slow', 'VB', 'O')
# ('as', 'RB', 'O')
# ('much', 'RB', 'O')
# ('as', 'IN', 'O')
# ('expected', 'VBN', 'O')
# ('and', 'CC', 'O')
# ('on', 'IN', 'O')
# ('expectations', 'NNS', 'O')
# ('that', 'IN', 'O')
# ('the', 'DT', 'O')
# ('Federal', 'NNP', 'O')
# ('Reserve', 'NNP', 'O')
# ('will', 'MD', 'O')
# ('hold', 'VB', 'O')
# ('its', 'PRP$', 'O')
# ('benchmark', 'JJ', 'B-NP')
# ('interest', 'NN', 'I-NP')
# ('rate', 'NN', 'B-NP')
# ('at', 'IN', 'O')
# ('its', 'PRP$', 'O')
# ('current', 'JJ', 'B-NP')
# ('level', 'NN', 'I-NP')
# (',', ',', 'O')
# ('after', 'IN', 'O')
# ('cutting', 'VBG', 'O')
# ('it', 'PRP', 'O')
# ('three', 'CD', 'O')
# ('times', 'NNS', 'O')
# ('this', 'DT', 'B-NP')
# ('year', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'B-NP')
# ('spread', 'NN', 'I-NP')
# ('between', 'IN', 'O')
# ('the', 'DT', 'O')
# ('2-year', 'JJ', 'O')
# ('and', 'CC', 'O')
# ('10-year', 'JJ', 'O')
# ('Treasuries', 'NNP', 'O')
# ('has', 'VBZ', 'O')
# ('now', 'RB', 'O')
# ('widened', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('the', 'DT', 'O')
# ('highest', 'JJS', 'O')
# ('level', 'NN', 'B-NP')
# ('since', 'IN', 'O')
# ('October', 'NNP', 'O')
# (',', ',', 'O')
# ('indicating', 'VBG', 'O')
# ('that', 'IN', 'O')
# ('investors', 'NNS', 'O')
# ('believe', 'VBP', 'O')
# ('the', 'DT', 'B-NP')
# ('global', 'JJ', 'I-NP')
# ('growth', 'NN', 'I-NP')
# ('scare', 'NN', 'B-NP')
# ('has', 'VBZ', 'O')
# ('been', 'VBN', 'O')
# ('mitigated', 'VBN', 'O')
# ('by', 'IN', 'O')
# ('rate', 'NN', 'B-NP')
# ('cuts', 'NNS', 'O')
# ('from', 'IN', 'O')
# ('the', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('other', 'JJ', 'O')
# ('central', 'JJ', 'O')
# ('banks', 'NNS', 'O')
# ('.', '.', 'O')
# ('U.S.', 'NNP', 'O')
# ('manufacturers', 'NNS', 'O')
# ('also', 'RB', 'O')
# ('sent', 'VBD', 'O')
# ('out', 'RP', 'O')
# ('warning', 'VBG', 'O')
# ('signs', 'NNS', 'O')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('Institute', 'NNP', 'O')
# ('for', 'IN', 'O')
# ('Supply', 'NNP', 'O')
# ('Management', 'NNP', 'O')
# ('reported', 'VBD', 'O')
# ('that', 'IN', 'O')
# ('manufacturing', 'NN', 'B-NP')
# ('activity', 'NN', 'B-NP')
# ('in', 'IN', 'O')
# ('the', 'DT', 'O')
# ('U.S.', 'NNP', 'O')
# ('contracted', 'VBD', 'O')
# ('for', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('fourth', 'JJ', 'I-NP')
# ('straight', 'JJ', 'I-NP')
# ('month', 'NN', 'I-NP')
# ('in', 'IN', 'O')
# ('November', 'NNP', 'O')
# ('.', '.', 'O')
# ('The', 'DT', 'B-NP')
# ('manufacturing', 'NN', 'I-NP')
# ('contraction', 'NN', 'B-NP')
# ('has', 'VBZ', 'O')
# ('been', 'VBN', 'O')
# ('a', 'DT', 'B-NP')
# ('key', 'JJ', 'I-NP')
# ('part', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('economic', 'JJ', 'I-NP')
# ('slowdown', 'NN', 'I-NP')
# ('narrative', 'JJ', 'O')
# ('.', '.', 'O')
# ('On', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('other', 'JJ', 'I-NP')
# ('hand', 'NN', 'I-NP')
# (',', ',', 'O')
# ('the', 'DT', 'O')
# ('ISM', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('non-manufacturing', 'JJ', 'B-NP')
# ('index', 'NN', 'I-NP')
# ('continues', 'VBZ', 'O')
# ('to', 'TO', 'O')
# ('expand', 'VB', 'O')
# (',', ',', 'O')
# ('meaning', 'VBG', 'O')
# ('the', 'DT', 'B-NP')
# ('service', 'NN', 'I-NP')
# ('sector', 'NN', 'B-NP')
# ('is', 'VBZ', 'O')
# ('still', 'RB', 'O')
# ('running', 'VBG', 'O')
# ('strong', 'JJ', 'O')
# ('.', '.', 'O')
# ('It', 'PRP', 'O')
# ('seemed', 'VBD', 'O')
# ('whatever', 'WDT', 'O')
# ('negative', 'JJ', 'O')
# ('turns', 'VBZ', 'O')
# ('the', 'DT', 'O')
# ('economic', 'JJ', 'O')
# ('data', 'NNS', 'O')
# ('took', 'VBD', 'O')
# ('in', 'IN', 'O')
# ('2019', 'CD', 'O')
# (',', ',', 'O')
# ('it', 'PRP', 'O')
# ('was', 'VBD', 'O')
# ('always', 'RB', 'O')
# ('offset', 'VBN', 'O')
# ('by', 'IN', 'O')
# ('strong', 'JJ', 'B-NP')
# ('consumer', 'NN', 'I-NP')
# ('spending', 'NN', 'B-NP')
# ('and', 'CC', 'O')
# ('a', 'DT', 'O')
# ('historically', 'RB', 'O')
# ('low', 'JJ', 'B-NP')
# ('unemployment', 'NN', 'I-NP')
# ('rate', 'NN', 'B-NP')
# ('-', ':', 'O')
# ('currently', 'RB', 'O')
# ('3.5', 'CD', 'O')
# ('percent', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('Two', 'CD', 'O')
# ('stocks', 'NNS', 'O')
# ('accounted', 'VBD', 'O')
# ('for', 'IN', 'O')
# ('nearly', 'RB', 'O')
# ('15', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('500', 'CD', 'O')
# ("'s", 'POS', 'O')
# ('gains', 'NNS', 'O')
# (',', ',', 'O')
# ('according', 'VBG', 'O')
# ('to', 'TO', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# ('Dow', 'NNP', 'O')
# ('Jones', 'NNP', 'O')
# ('Indices', 'NNP', 'O')
# ('.', '.', 'O')
# ('Apple', 'NNP', 'O')
# ('was', 'VBD', 'O')
# ('up', 'RB', 'O')
# ('85', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('and', 'CC', 'O')
# ('Microsoft', 'NNP', 'O')
# ('was', 'VBD', 'O')
# ('up', 'RB', 'O')
# ('15', 'CD', 'O')
# ('%', 'NN', 'B-NP')
# ('.', '.', 'O')
# ('The', 'DT', 'O')
# ('two', 'CD', 'O')
# ('tech', 'JJ', 'O')
# ('giants', 'NNS', 'O')
# ('are', 'VBP', 'O')
# ('the', 'DT', 'O')
# ('only', 'JJ', 'O')
# ('two', 'CD', 'O')
# ('U.S.', 'NNP', 'O')
# ('companies', 'NNS', 'O')
# ('with', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('market', 'NN', 'I-NP')
# ('capitalization', 'NN', 'B-NP')
# ('of', 'IN', 'O')
# ('more', 'JJR', 'O')
# ('than', 'IN', 'O')
# ('$', '$', 'O')
# ('1', 'CD', 'O')
# ('trillion', 'CD', 'O')
# ('.', '.', 'O')
# ('And', 'CC', 'O')
# ('in', 'IN', 'O')
# ('a', 'DT', 'B-NP')
# ('cap-weighted', 'JJ', 'I-NP')
# ('index', 'NN', 'I-NP')
# ('like', 'IN', 'O')
# ('the', 'DT', 'O')
# ('S', 'NNP', 'O')
# ('&', 'CC', 'O')
# ('P', 'NNP', 'O')
# (',', ',', 'O')
# ('they', 'PRP', 'O')
# ('have', 'VBP', 'O')
# ('an', 'DT', 'B-NP')
# ('outsized', 'JJ', 'I-NP')
# ('influence', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('Facebook', 'NNP', 'O')
# (',', ',', 'O')
# ('Alphabet', 'NNP', 'O')
# ('(', '(', 'O')
# ('Google', 'NNP', 'O')
# ("'s", 'POS', 'O')
# ('parent', 'NN', 'B-NP')
# ('company', 'NN', 'B-NP')
# (')', ')', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('Amazon', 'NNP', 'O')
# ('also', 'RB', 'O')
# ('contributed', 'VBD', 'O')
# ('.', '.', 'O')
# ('Semiconductor', 'NN', 'B-NP')
# ('companies', 'NNS', 'O')
# ('were', 'VBD', 'O')
# ('also', 'RB', 'O')
# ('big', 'JJ', 'O')
# ('gainers', 'NNS', 'O')
# ('with', 'IN', 'O')
# ('Advance', 'NNP', 'O')
# ('Micro', 'NNP', 'O')
# ('Devices', 'NNPS', 'O')
# (',', ',', 'O')
# ('Lam', 'NNP', 'O')
# ('Research', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('KLA', 'NNP', 'O')
# ('Corp.', 'NNP', 'O')
# ('leading', 'VBG', 'O')
# ('the', 'DT', 'B-NP')
# ('index', 'NN', 'I-NP')
# ('with', 'IN', 'O')
# ('the', 'DT', 'O')
# ('largest', 'JJS', 'O')
# ('gains', 'NNS', 'O')
# ('.', '.', 'O')
# ('In', 'IN', 'O')
# ('the', 'DT', 'B-NP')
# ('end', 'NN', 'I-NP')
# (',', ',', 'O')
# ('2019', 'CD', 'O')
# ('enjoyed', 'VBD', 'O')
# ('a', 'DT', 'B-NP')
# ('confluence', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('booming', 'VBG', 'O')
# ('technology', 'NN', 'B-NP')
# ('and', 'CC', 'O')
# ('easy', 'JJ', 'B-NP')
# ('money', 'NN', 'I-NP')
# ('from', 'IN', 'O')
# ('the', 'DT', 'O')
# ('Fed', 'NNP', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('it', 'PRP', 'O')
# ('proved', 'VBD', 'O')
# ('the', 'DT', 'O')
# ('age-old', 'JJ', 'O')
# ('Wall', 'NNP', 'O')
# ('Street', 'NNP', 'O')
# ('maxim', 'VBD', 'O')
# ('that', 'IN', 'O')
# ('markets', 'NNS', 'O')
# ('climb', 'VBP', 'O')
# ('a', 'DT', 'B-NP')
# ('wall', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('worry', 'NN', 'B-NP')
# ('—', 'NNP', 'O')
# ('perhaps', 'RB', 'O')
# ('more', 'RBR', 'O')
# ('than', 'IN', 'O')
# ('any', 'DT', 'B-NP')
# ('other', 'JJ', 'I-NP')
# ('year', 'NN', 'I-NP')
# ('.', '.', 'O')
# ('Got', 'NNP', 'O')
# ('a', 'DT', 'B-NP')
# ('confidential', 'JJ', 'I-NP')
# ('news', 'NN', 'I-NP')
# ('tip', 'NN', 'B-NP')
# ('?', '.', 'O')
# ('We', 'PRP', 'O')
# ('want', 'VBP', 'O')
# ('to', 'TO', 'O')
# ('hear', 'VB', 'O')
# ('from', 'IN', 'O')
# ('you', 'PRP', 'O')
# ('.', '.', 'O')
# ('Sign', 'VB', 'O')
# ('up', 'RP', 'O')
# ('for', 'IN', 'O')
# ('free', 'JJ', 'O')
# ('newsletters', 'NNS', 'O')
# ('and', 'CC', 'O')
# ('get', 'VB', 'O')
# ('more', 'JJR', 'O')
# ('CNBC', 'NNP', 'O')
# ('delivered', 'VBD', 'O')
# ('to', 'TO', 'O')
# ('your', 'PRP$', 'O')
# ('inbox', 'NN', 'B-NP')
# ('Get', 'VB', 'O')
# ('this', 'DT', 'O')
# ('delivered', 'VBN', 'O')
# ('to', 'TO', 'O')
# ('your', 'PRP$', 'O')
# ('inbox', 'NN', 'B-NP')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('more', 'JJR', 'O')
# ('info', 'NNS', 'O')
# ('about', 'IN', 'O')
# ('our', 'PRP$', 'O')
# ('products', 'NNS', 'O')
# ('and', 'CC', 'O')
# ('services', 'NNS', 'O')
# ('.', '.', 'O')
# ('©', 'JJ', 'O')
# ('2022', 'CD', 'O')
# ('CNBC', 'NNP', 'O')
# ('LLC', 'NNP', 'O')
# ('.', '.', 'O')
# ('All', 'NNP', 'O')
# ('Rights', 'NNPS', 'O')
# ('Reserved', 'NNP', 'O')
# ('.', '.', 'O')
# ('A', 'DT', 'B-NP')
# ('Division', 'NN', 'I-NP')
# ('of', 'IN', 'O')
# ('NBCUniversal', 'NNP', 'O')
# ('Data', 'NNP', 'O')
# ('is', 'VBZ', 'O')
# ('a', 'DT', 'B-NP')
# ('real-time', 'JJ', 'I-NP')
# ('snapshot', 'NN', 'I-NP')
# ('*Data', 'NNP', 'O')
# ('is', 'VBZ', 'O')
# ('delayed', 'VBN', 'O')
# ('at', 'IN', 'O')
# ('least', 'JJS', 'O')
# ('15', 'CD', 'O')
# ('minutes', 'NNS', 'O')
# ('.', '.', 'O')
# ('Global', 'NNP', 'O')
# ('Business', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('Financial', 'NNP', 'O')
# ('News', 'NNP', 'O')
# (',', ',', 'O')
# ('Stock', 'NNP', 'O')
# ('Quotes', 'NNP', 'O')
# (',', ',', 'O')
# ('and', 'CC', 'O')
# ('Market', 'NNP', 'O')
# ('Data', 'NNP', 'O')
# ('and', 'CC', 'O')
# ('Analysis', 'NNP', 'O')
# ('.', '.', 'O')
# ('Data', 'NNP', 'O')
# ('also', 'RB', 'O')
# ('provided', 'VBN', 'O')
# ('by', 'IN', 'O')

# %%
# NER using NLTK
for chunk in nltk.ne_chunk(pos_tag(nltk.word_tokenize(content))):
  if hasattr(chunk, 'label'):
    print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# PERSON Nasdaq
# PERSON Apple
# PERSON Microsoft
# ORGANIZATION Dow Jones Industrial Average
# ORGANIZATION Federal Reserve
# ORGANIZATION Federal Reserve
# ORGANIZATION Fed
# ORGANIZATION Fed
# ORGANIZATION Fed
# ORGANIZATION Fed
# PERSON Fed Chairman Jerome Powell
# ORGANIZATION Fed
# GPE U.S.
# PERSON Donald Trump
# GPE China
# LOCATION North
# ORGANIZATION American Free Trade
# GPE Canada
# GPE Mexico
# PERSON Trump
# ORGANIZATION House
# ORGANIZATION United
# PERSON Trump
# ORGANIZATION NAFTA
# ORGANIZATION Senate
# ORGANIZATION Trump
# GPE China
# GPE U.S.
# GPE China
# ORGANIZATION European Union
# PERSON Brexit
# ORGANIZATION International Monetary Fund
# GPE EU
# GPE U.S.
# GPE China
# PERSON Energy
# LOCATION West Texas
# GPE Saudi
# PERSON Aramco
# GPE August
# GPE Europe
# GPE U.S.
# ORGANIZATION Federal Reserve
# ORGANIZATION Treasuries
# ORGANIZATION Fed
# GPE U.S.
# ORGANIZATION Institute
# PERSON Supply Management
# GPE U.S.
# ORGANIZATION ISM
# PERSON P Dow Jones Indices
# PERSON Apple
# PERSON Microsoft
# GPE U.S.
# PERSON Facebook
# GPE Alphabet
# ORGANIZATION Google
# PERSON Amazon
# PERSON Advance Micro Devices
# PERSON Lam Research
# ORGANIZATION KLA
# ORGANIZATION Fed
# FACILITY Wall Street
# ORGANIZATION CNBC
# ORGANIZATION CNBC
# ORGANIZATION All Rights Reserved
# ORGANIZATION NBCUniversal Data
# PERSON Global Business
# ORGANIZATION Financial News
# PERSON Stock Quotes
# PERSON Market Data
# GPE Analysis
# PERSON Data

# %%
# NER using SpaCy
nlp = en_core_web_sm.load()

# if we want to try this on real large datasets, we can use the medium and large models in spacy
# nlp = spacy.load('en_core_web_md')
# nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp(content)
for item in doc.ents:
  print (item.text, item.label_)
# Out:
# a year DATE
# 2013 DATE
# Twelve months ago DATE
# more than 28% PERCENT
# 2019 DATE
# 31% PERCENT
# 1997 DATE
# one CARDINAL
# 29.6% PERCENT
# 2013 DATE
# Nasdaq ORG
# 35% PERCENT
# Apple ORG
# Microsoft ORG
# trillion-dollar MONEY
# 22% PERCENT
# a year DATE
# Federal Reserve ORG
# The year DATE
# One CARDINAL
# 2019 DATE
# December 2018 DATE
# just 0.2% PERCENT
# 20% PERCENT
# 2018 DATE
# more than 6% PERCENT
# 2,485.74 CARDINAL
# Dec. 31, 2018 DATE
# the final hours TIME
# 2019 DATE
# 3,220 CARDINAL
# S&P ORG
# 2019 DATE
# about 10% PERCENT
# 2018 DATE
# roughly 2,900 CARDINAL
# 90 years DATE
# 9.8% PERCENT
# 2019 DATE
# the Federal Reserve ORG
# Fed ORG
# four CARDINAL
# 2018 DATE
# December 2018 DATE
# 2.5 percent PERCENT
# 2019 DATE
# Fed ORG
# three CARDINAL
# Fed ORG
# 1.50% to 1.75% PERCENT
# Fed ORG
# 2020 DATE
# Fed ORG
# Jerome Powell PERSON
# Fed ORG
# U.S. GPE
# Donald Trump PERSON
# China GPE
# the North American Free Trade Agreement GPE
# Canada GPE
# Mexico GPE
# the year DATE
# Trump PERSON
# the year DATE
# the year DATE
# House ORG
# the United States GPE
# Trump PERSON
# NAFTA ORG
# Senate ORG
# Trump PERSON
# one CARDINAL
# China GPE
# U.S. GPE
# China GPE
# the coming weeks DATE
# 2019 DATE
# U.K. GPE
# the European Union ORG
# Brexit GPE
# The International Monetary Fund ORG
# 2019 DATE
# 3% PERCENT
# the year DATE
# U.K. GPE
# EU ORG
# one CARDINAL
# U.S. GPE
# China GPE
# 2019 DATE
# West Texas Intermediate PRODUCT
# more than $60 MONEY
# one CARDINAL
# 2019 DATE
# Saudi Aramco's GPE
# $2 trillion MONEY
# August DATE
# one or two years DATE
# $17 trillion MONEY
# Europe LOC
# less than zero CARDINAL
# the year DATE
# U.S. GPE
# the Federal Reserve ORG
# three CARDINAL
# this year DATE
# October DATE
# Fed ORG
# U.S. GPE
# 2019 DATE
# The Institute for Supply Management ORG
# U.S. GPE
# the fourth straight month DATE
# November DATE
# ISM ORG
# 2019 DATE
# 3.5 percent PERCENT
# Two CARDINAL
# nearly 15% PERCENT
# the S&P 500's ORG
# S&P Dow Jones Indices ORG
# Apple ORG
# 85% PERCENT
# Microsoft ORG
# 15% PERCENT
# two CARDINAL
# only two CARDINAL
# U.S. GPE
# more than $1 trillion MONEY
# S&P ORG
# Alphabet PERSON
# Google ORG
# Amazon ORG
# Advance Micro Devices ORG
# Lam Research ORG
# KLA Corp. ORG
# the end, 2019 DATE
# Fed ORG
# CNBC ORG
# 2022 CARDINAL
# CNBC ORG
# at least 15 minutes TIME
# Global Business and Financial News ORG
# Market Data ORG
# Data ORG

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
# visualize
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that began with investors courting a bear market and ended with the biggest gains from stocks since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twelve months ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few could have imagined the S&amp;P 500 delivering a gain of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 28%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . It was a performance that flirted with the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  gain of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  that came very close to topping the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  return of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .  The tech-heavy
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  did even better, posting a gain of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  as money flowed to the tech giants, cementing
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's position as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     trillion-dollar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  companies. The Dow Jones Industrial Average was up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# .  It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  filled with fears that were never realized: a global economic slowdown, disruptive trade wars and potential missteps from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Federal Reserve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  policy.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  also revealed an unforeseen boom in the tech sector that drove the major stock indexes ever higher.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the key's to the market's
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  success was starting from a low base.  A steep sell-off in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 2018
#     <span style="font-size: 0.8em; font-weig

# %%
# lemmatization
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(content) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [(' ', 'SPACE', ' '),
#  ('year', 'NOUN', 'year'),
#  ('began', 'VERB', 'begin'),
#  ('investors', 'NOUN', 'investor'),
#  ('courting', 'VERB', 'court'),
#  ('bear', 'NOUN', 'bear'),
#  ('market', 'NOUN', 'market'),
#  ('ended', 'VERB', 'end'),
#  ('biggest', 'ADJ', 'big'),
#  ('gains', 'NOUN', 'gain'),
#  ('stocks', 'NOUN', 'stock'),
#  ('2013', 'NUM', '2013'),
#  ('months', 'NOUN', 'month'),
#  ('ago', 'ADV', 'ago'),
#  ('imagined', 'VERB', 'imagine'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('delivering', 'VERB', 'deliver'),
#  ('gain', 'NOUN', 'gain'),
#  ('28', 'NUM', '28'),
#  ('%', 'NOUN', '%'),
#  ('2019', 'NUM', '2019'),
#  ('performance', 'NOUN', 'performance'),
#  ('flirted', 'VERB', 'flirt'),
#  ('31', 'NUM', '31'),
#  ('%', 'NOUN', '%'),
#  ('gain', 'NOUN', 'gain'),
#  ('1997', 'NUM', '1997'),
#  ('came', 'VERB', 'come'),
#  ('close', 'ADV', 'close'),
#  ('topping', 'VERB', 'top'),
#  ('29.6', 'NUM', '29.6'),
#  ('%', 'NOUN', '%'),
#  ('return', 'NOUN', 'return'),
#  ('2013', 'NUM', '2013'),
#  (' ', 'SPACE', ' '),
#  ('tech', 'NOUN', 'tech'),
#  ('heavy', 'ADJ', 'heavy'),
#  ('Nasdaq', 'PROPN', 'Nasdaq'),
#  ('better', 'ADV', 'better'),
#  ('posting', 'VERB', 'post'),
#  ('gain', 'NOUN', 'gain'),
#  ('35', 'NUM', '35'),
#  ('%', 'NOUN', '%'),
#  ('money', 'NOUN', 'money'),
#  ('flowed', 'VERB', 'flow'),
#  ('tech', 'NOUN', 'tech'),
#  ('giants', 'NOUN', 'giant'),
#  ('cementing', 'VERB', 'cement'),
#  ('Apple', 'PROPN', 'Apple'),
#  ('Microsoft', 'PROPN', 'Microsoft'),
#  ('position', 'NOUN', 'position'),
#  ('trillion', 'NUM', 'trillion'),
#  ('dollar', 'NOUN', 'dollar'),
#  ('companies', 'NOUN', 'company'),
#  ('Dow', 'PROPN', 'Dow'),
#  ('Jones', 'PROPN', 'Jones'),
#  ('Industrial', 'PROPN', 'Industrial'),
#  ('Average', 'PROPN', 'Average'),
#  ('22', 'NUM', '22'),
#  ('%', 'NOUN', '%'),
#  (' ', 'SPACE', ' '),
#  ('year', 'NOUN', 'year'),
#  ('filled', 'VERB', 'fill'),
#  ('fears', 'NOUN', 'fear'),
#  ('realized', 'VERB', 'realize'),
#  ('global', 'ADJ', 'global'),
#  ('economic', 'ADJ', 'economic'),
#  ('slowdown', 'NOUN', 'slowdown'),
#  ('disruptive', 'ADJ', 'disruptive'),
#  ('trade', 'NOUN', 'trade'),
#  ('wars', 'NOUN', 'war'),
#  ('potential', 'ADJ', 'potential'),
#  ('missteps', 'NOUN', 'misstep'),
#  ('Federal', 'PROPN', 'Federal'),
#  ('Reserve', 'PROPN', 'Reserve'),
#  ('policy', 'NOUN', 'policy'),
#  ('year', 'NOUN', 'year'),
#  ('revealed', 'VERB', 'reveal'),
#  ('unforeseen', 'ADJ', 'unforeseen'),
#  ('boom', 'NOUN', 'boom'),
#  ('tech', 'NOUN', 'tech'),
#  ('sector', 'NOUN', 'sector'),
#  ('drove', 'VERB', 'drive'),
#  ('major', 'ADJ', 'major'),
#  ('stock', 'NOUN', 'stock'),
#  ('indexes', 'NOUN', 'index'),
#  ('higher', 'ADV', 'higher'),
#  ('key', 'NOUN', 'key'),
#  ('market', 'NOUN', 'market'),
#  ('2019', 'NUM', '2019'),
#  ('success', 'NOUN', 'success'),
#  ('starting', 'VERB', 'start'),
#  ('low', 'ADJ', 'low'),
#  ('base', 'NOUN', 'base'),
#  (' ', 'SPACE', ' '),
#  ('steep', 'ADJ', 'steep'),
#  ('sell', 'NOUN', 'sell'),
#  ('December', 'PROPN', 'December'),
#  ('2018', 'NUM', '2018'),
#  ('left', 'VERB', 'leave'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('0.2', 'NUM', '0.2'),
#  ('%', 'NOUN', '%'),
#  ('officially', 'ADV', 'officially'),
#  ('hitting', 'VERB', 'hit'),
#  ('bear', 'NOUN', 'bear'),
#  ('market', 'NOUN', 'market'),
#  ('defined', 'VERB', 'define'),
#  ('20', 'NUM', '20'),
#  ('%', 'NOUN', '%'),
#  ('decline', 'NOUN', 'decline'),
#  ('closing', 'NOUN', 'closing'),
#  ('peak', 'NOUN', 'peak'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('ended', 'VERB', 'end'),
#  ('2018', 'NUM', '2018'),
#  ('loss', 'NOUN', 'loss'),
#  ('6', 'NUM', '6'),
#  ('%', 'NOUN', '%'),
#  ('closing', 'VERB', 'close'),
#  ('2,485.74', 'NUM', '2,485.74'),
#  ('Dec.', 'PROPN', 'December'),
#  ('31', 'NUM', '31'),
#  ('2018', 'NUM', '2018'),
#  ('final', 'ADJ', 'final'),
#  ('hours', 'NOUN', 'hour'),
#  ('trading', 'NOUN', 'trading'),
#  ('2019', 'NUM', '2019'),
#  ('trading', 'VERB', 'trade'),
#  ('3,220', 'NUM', '3,220'),
#  ('perspective', 'NOUN', 'perspective'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('finishing', 'VERB', 'finish'),
#  ('2019', 'NUM', '2019'),
#  ('10', 'NUM', '10'),
#  ('%', 'NOUN', '%'),
#  ('2018', 'NUM', '2018'),
#  ('high', 'ADJ', 'high'),
#  ('roughly', 'ADV', 'roughly'),
#  ('2,900', 'NUM', '2,900'),
#  ('close', 'ADJ', 'close'),
#  ('average', 'ADJ', 'average'),
#  ('return', 'NOUN', 'return'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('90', 'NUM', '90'),
#  ('years', 'NOUN', 'year'),
#  ('9.8', 'NUM', '9.8'),
#  ('%', 'NOUN', '%'),
#  ('stock', 'NOUN', 'stock'),
#  ('market', 'NOUN', 'market'),
#  ('gains', 'NOUN', 'gain'),
#  ('2019', 'NUM', '2019'),
#  ('attributed', 'VERB', 'attribute'),
#  ('dramatic', 'ADJ', 'dramatic'),
#  ('policy', 'NOUN', 'policy'),
#  ('shift', 'NOUN', 'shift'),
#  ('Federal', 'PROPN', 'Federal'),
#  ('Reserve', 'PROPN', 'Reserve'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('raised', 'VERB', 'raise'),
#  ('rates', 'NOUN', 'rate'),
#  ('times', 'NOUN', 'time'),
#  ('2018', 'NUM', '2018'),
#  ('including', 'VERB', 'include'),
#  ('December', 'PROPN', 'December'),
#  ('2018', 'NUM', '2018'),
#  ('hike', 'NOUN', 'hike'),
#  ('took', 'VERB', 'take'),
#  ('key', 'ADJ', 'key'),
#  ('rate', 'NOUN', 'rate'),
#  ('2.5', 'NUM', '2.5'),
#  ('percent', 'NOUN', 'percent'),
#  ('different', 'ADJ', 'different'),
#  ('story', 'NOUN', 'story'),
#  ('2019', 'NUM', '2019'),
#  ('change', 'NOUN', 'change'),
#  ('heart', 'NOUN', 'heart'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('lowered', 'VERB', 'lower'),
#  ('rates', 'NOUN', 'rate'),
#  ('times', 'NOUN', 'time'),
#  ('Falling', 'VERB', 'fall'),
#  ('interest', 'NOUN', 'interest'),
#  ('rates', 'NOUN', 'rate'),
#  ('sent', 'VERB', 'send'),
#  ('investors', 'NOUN', 'investor'),
#  ('quest', 'NOUN', 'quest'),
#  ('yield', 'NOUN', 'yield'),
#  ('forcing', 'VERB', 'force'),
#  ('money', 'NOUN', 'money'),
#  ('stocks', 'NOUN', 'stock'),
#  ('expected', 'VERB', 'expect'),
#  ('appreciate', 'VERB', 'appreciate'),
#  ('pay', 'VERB', 'pay'),
#  ('dividends', 'NOUN', 'dividend'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('key', 'ADJ', 'key'),
#  ('rate', 'NOUN', 'rate'),
#  ('range', 'NOUN', 'range'),
#  ('1.50', 'NUM', '1.50'),
#  ('%', 'NOUN', '%'),
#  ('1.75', 'NUM', '1.75'),
#  ('%', 'NOUN', '%'),
#  ('Additionally', 'ADV', 'additionally'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('said', 'VERB', 'say'),
#  ('expects', 'VERB', 'expect'),
#  ('leave', 'VERB', 'leave'),
#  ('rates', 'NOUN', 'rate'),
#  ('unchanged', 'ADJ', 'unchanged'),
#  ('2020', 'NUM', '2020'),
#  ('giving', 'VERB', 'give'),
#  ('investors', 'NOUN', 'investor'),
#  ('clarity', 'NOUN', 'clarity'),
#  ('remain', 'VERB', 'remain'),
#  ('historically', 'ADV', 'historically'),
#  ('low', 'ADJ', 'low'),
#  ('rates', 'NOUN', 'rate'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('Chairman', 'PROPN', 'Chairman'),
#  ('Jerome', 'PROPN', 'Jerome'),
#  ('Powell', 'PROPN', 'Powell'),
#  ('described', 'VERB', 'describe'),
#  ('central', 'ADJ', 'central'),
#  ('bank', 'NOUN', 'bank'),
#  ('moves', 'NOUN', 'move'),
#  ('insurance', 'NOUN', 'insurance'),
#  ('rate', 'NOUN', 'rate'),
#  ('cuts', 'NOUN', 'cut'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('wanted', 'VERB', 'want'),
#  ('ensure', 'VERB', 'ensure'),
#  ('slowing', 'VERB', 'slow'),
#  ('global', 'ADJ', 'global'),
#  ('economy', 'NOUN', 'economy'),
#  ('drag', 'VERB', 'drag'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('biggest', 'ADJ', 'big'),
#  ('uncertainties', 'NOUN', 'uncertainty'),
#  ('global', 'ADJ', 'global'),
#  ('economic', 'ADJ', 'economic'),
#  ('growth', 'NOUN', 'growth'),
#  ('President', 'PROPN', 'President'),
#  ('Donald', 'PROPN', 'Donald'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('trade', 'NOUN', 'trade'),
#  ('negotiations', 'NOUN', 'negotiation'),
#  ('China', 'PROPN', 'China'),
#  ('-', 'NOUN', '-'),
#  ('crafting', 'NOUN', 'crafting'),
#  ('North', 'PROPN', 'North'),
#  ('American', 'PROPN', 'American'),
#  ('Free', 'PROPN', 'Free'),
#  ('Trade', 'PROPN', 'Trade'),
#  ('Agreement', 'PROPN', 'Agreement'),
#  ('Canada', 'PROPN', 'Canada'),
#  ('Mexico', 'PROPN', 'Mexico'),
#  ('trade', 'NOUN', 'trade'),
#  ('war', 'NOUN', 'war'),
#  ('headlines', 'NOUN', 'headline'),
#  ('dominated', 'VERB', 'dominate'),
#  ('financial', 'ADJ', 'financial'),
#  ('news', 'NOUN', 'news'),
#  ('year', 'NOUN', 'year'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('tariffs', 'NOUN', 'tariff'),
#  ('threats', 'NOUN', 'threat'),
#  ('tariffs', 'NOUN', 'tariff'),
#  ('sent', 'VERB', 'send'),
#  ('indexes', 'NOUN', 'index'),
#  ('frightfully', 'ADV', 'frightfully'),
#  ('lower', 'ADJ', 'low'),
#  ('pronouncements', 'NOUN', 'pronouncement'),
#  ('usually', 'ADV', 'usually'),
#  ('tweet', 'PROPN', 'tweet'),
#  ('deals', 'NOUN', 'deal'),
#  ('coming', 'VERB', 'come'),
#  ('send', 'VERB', 'send'),
#  ('markets', 'NOUN', 'market'),
#  ('higher', 'ADJ', 'high'),
#  ('course', 'NOUN', 'course'),
#  ('year', 'NOUN', 'year'),
#  ('trade', 'NOUN', 'trade'),
#  ('war', 'NOUN', 'war'),
#  ('transient', 'ADJ', 'transient'),
#  ('effects', 'NOUN', 'effect'),
#  ('stock', 'NOUN', 'stock'),
#  ('market', 'NOUN', 'market'),
#  ('year', 'NOUN', 'year'),
#  ('came', 'VERB', 'come'),
#  ('close', 'NOUN', 'close'),
#  ('House', 'PROPN', 'House'),
#  ('passed', 'VERB', 'pass'),
#  ('United', 'PROPN', 'United'),
#  ('States', 'PROPN', 'States'),
#  ('Mexico', 'PROPN', 'Mexico'),
#  ('Canada', 'PROPN', 'Canada'),
#  ('Agreement', 'PROPN', 'Agreement'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('replacement', 'NOUN', 'replacement'),
#  ('NAFTA', 'PROPN', 'NAFTA'),
#  ('Senate', 'PROPN', 'Senate'),
#  ('expected', 'VERB', 'expect'),
#  ('pass', 'VERB', 'pass'),
#  ('soon', 'ADV', 'soon'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('administration', 'NOUN', 'administration'),
#  ('come', 'VERB', 'come'),
#  ('phase', 'NOUN', 'phase'),
#  ('trade', 'NOUN', 'trade'),
#  ('agreement', 'NOUN', 'agreement'),
#  ('China', 'PROPN', 'China'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('China', 'PROPN', 'China'),
#  ('officials', 'NOUN', 'official'),
#  ('sign', 'VERB', 'sign'),
#  ('deal', 'NOUN', 'deal'),
#  ('coming', 'VERB', 'come'),
#  ('weeks', 'NOUN', 'week'),
#  ('hardly', 'ADV', 'hardly'),
#  ('means', 'VERB', 'mean'),
#  ('end', 'NOUN', 'end'),
#  ('sure', 'ADJ', 'sure'),
#  ('difficult', 'ADJ', 'difficult'),
#  ('negotiations', 'NOUN', 'negotiation'),
#  ('initial', 'ADJ', 'initial'),
#  ('agreement', 'NOUN', 'agreement'),
#  ('marked', 'VERB', 'mark'),
#  ('pause', 'NOUN', 'pause'),
#  ('trade', 'NOUN', 'trade'),
#  ('war', 'NOUN', 'war'),
#  ('escalation', 'NOUN', 'escalation'),
#  ('sharply', 'ADV', 'sharply'),
#  ('boosted', 'VERB', 'boost'),
#  ('markets', 'NOUN', 'market'),
#  ('2019', 'NUM', '2019'),
#  ('investors', 'NOUN', 'investor'),
#  ('fretted', 'VERB', 'fret'),
#  ('slowing', 'VERB', 'slow'),
#  ('global', 'ADJ', 'global'),
#  ('economy', 'NOUN', 'economy'),
#  ('fears', 'NOUN', 'fear'),
#  ('stemmed', 'VERB', 'stem'),
#  ('disruptive', 'ADJ', 'disruptive'),
#  ('trade', 'NOUN', 'trade'),
#  ('wars', 'NOUN', 'war'),
#  ('tariffs', 'NOUN', 'tariff'),
#  ('U.K.', 'PROPN', 'U.K.'),
#  ('plans', 'NOUN', 'plan'),
#  ('depart', 'VERB', 'depart'),
#  ('European', 'PROPN', 'European'),
#  ('Union', 'PROPN', 'Union'),
#  ('called', 'VERB', 'call'),
#  ('Brexit', 'PROPN', 'Brexit'),
#  ('fears', 'NOUN', 'fear'),
#  ('voters', 'NOUN', 'voter'),
#  ('world', 'NOUN', 'world'),
#  ('shifting', 'VERB', 'shift'),
#  ('far', 'ADV', 'far'),
#  ('left', 'ADJ', 'left'),
#  ('International', 'PROPN', 'International'),
#  ('Monetary', 'PROPN', 'Monetary'),
#  ('Fund', 'PROPN', 'Fund'),
#  ('recently', 'ADV', 'recently'),
#  ('downgraded', 'VERB', 'downgrade'),
#  ('2019', 'NUM', '2019'),
#  ('estimate', 'NOUN', 'estimate'),
#  ('global', 'ADJ', 'global'),
#  ('economic', 'ADJ', 'economic'),
#  ('growth', 'NOUN', 'growth'),
#  ('3', 'NUM', '3'),
#  ('%', 'NOUN', '%'),
#  ('lowest', 'ADJ', 'low'),
#  ('financial', 'ADJ', 'financial'),
#  ('crisis', 'NOUN', 'crisis'),
#  ('year', 'NOUN', 'year'),
#  ('came', 'VERB', 'come'),
#  ('close', 'NOUN', 'close'),
#  ('appeared', 'VERB', 'appear'),
#  ('U.K.', 'PROPN', 'U.K.'),
#  ('likely', 'ADV', 'likely'),
#  ('achieve', 'VERB', 'achieve'),
#  ('negotiated', 'VERB', 'negotiate'),
#  ('exit', 'NOUN', 'exit'),
#  ('EU', 'PROPN', 'EU'),
#  ('versus', 'ADP', 'versus'),
#  ('hard', 'ADJ', 'hard'),
#  ('trade', 'NOUN', 'trade'),
#  ('tensions', 'NOUN', 'tension'),
#  ('eased', 'VERB', 'ease'),
#  ('phase', 'NOUN', 'phase'),
#  ('deal', 'NOUN', 'deal'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('China', 'PROPN', 'China'),
#  ('economists', 'NOUN', 'economist'),
#  ('expressing', 'VERB', 'express'),
#  ('hopes', 'NOUN', 'hope'),
#  ('global', 'ADJ', 'global'),
#  ('economic', 'ADJ', 'economic'),
#  ('slowdown', 'NOUN', 'slowdown'),
#  ('bottoming', 'VERB', 'bottom'),
#  ('Energy', 'NOUN', 'energy'),
#  ('worst', 'ADV', 'worst'),
#  ('performing', 'VERB', 'perform'),
#  ('sector', 'NOUN', 'sector'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('2019', 'NUM', '2019'),
#  ('oil', 'NOUN', 'oil'),
#  ('fuel', 'NOUN', 'fuel'),
#  ('capitalism', 'NOUN', 'capitalism'),
#  ('depressed', 'ADJ', 'depressed'),
#  ('prices', 'NOUN', 'price'),
#  ('helped', 'VERB', 'help'),
#  ('bolster', 'VERB', 'bolster'),
#  ('economic', 'ADJ', 'economic'),
#  ('activity', 'NOUN', 'activity'),
#  ('globe', 'NOUN', 'globe'),
#  ('recent', 'ADJ', 'recent'),
#  ('uptick', 'NOUN', 'uptick'),
#  ('prices', 'NOUN', 'price'),
#  ('West', 'PROPN', 'West'),
#  ('Texas', 'PROPN', 'Texas'),
#  ('Intermediate', 'PROPN', 'Intermediate'),
#  ('crude', 'ADJ', 'crude'),
#  ('futures', 'NOUN', 'future'),
#  ('trading', 'VERB', 'trade'),
#  ('$', 'SYM', '$'),
#  ('60', 'NUM', '60'),
#  ('barrel', 'NOUN', 'barrel'),
#  ('historical', 'ADJ', 'historical'),
#  ('standards', 'NOUN', 'standard'),
#  ('hardly', 'ADV', 'hardly'),
#  ('disruptive', 'ADJ', 'disruptive'),
#  ('Despite', 'SCONJ', 'despite'),
#  ('sluggish', 'ADJ', 'sluggish'),
#  ('energy', 'NOUN', 'energy'),
#  ('markets', 'NOUN', 'market'),
#  ('highlights', 'NOUN', 'highlight'),
#  ('2019', 'NUM', '2019'),
#  ('Saudi', 'PROPN', 'Saudi'),
#  ('Aramco', 'PROPN', 'Aramco'),
#  ('initial', 'ADJ', 'initial'),
#  ('public', 'ADJ', 'public'),
#  ('stock', 'NOUN', 'stock'),
#  ('offering', 'NOUN', 'offering'),
#  ('oil', 'NOUN', 'oil'),
#  ('giant', 'NOUN', 'giant'),
#  ('reached', 'VERB', 'reach'),
#  ('valuation', 'NOUN', 'valuation'),
#  ('$', 'SYM', '$'),
#  ('2', 'NUM', '2'),
#  ('trillion', 'NUM', 'trillion'),
#  ('valuable', 'ADJ', 'valuable'),
#  ('company', 'NOUN', 'company'),
#  ('history', 'NOUN', 'history'),
#  ('August', 'PROPN', 'August'),
#  ('investors', 'NOUN', 'investor'),
#  ('began', 'VERB', 'begin'),
#  ('parsing', 'VERB', 'parse'),
#  ('meaning', 'NOUN', 'meaning'),
#  ('rare', 'ADJ', 'rare'),
#  ('market', 'NOUN', 'market'),
#  ('phenomena', 'NOUN', 'phenomenon'),
#  ('known', 'VERB', 'know'),
#  ('inverted', 'VERB', 'invert'),
#  ('yield', 'NOUN', 'yield'),
#  ('curve', 'NOUN', 'curve'),
#  (' ', 'SPACE', ' '),
#  ('occurs', 'VERB', 'occur'),
#  ('short', 'ADJ', 'short'),
#  ('term', 'NOUN', 'term'),
#  ('interest', 'NOUN', 'interest'),
#  ('rates', 'NOUN', 'rate'),
#  ('higher', 'ADJ', 'high'),
#  ('longer', 'ADJ', 'long'),
#  ('term', 'NOUN', 'term'),
#  ('rates', 'NOUN', 'rate'),
#  ('bad', 'ADJ', 'bad'),
#  ('sign', 'NOUN', 'sign'),
#  ('economy', 'NOUN', 'economy'),
#  ('Historically', 'ADV', 'historically'),
#  ('yield', 'NOUN', 'yield'),
#  ('curve', 'NOUN', 'curve'),
#  ('inverts', 'NOUN', 'invert'),
#  ('recession', 'NOUN', 'recession'),
#  ('follows', 'VERB', 'follow'),
#  ('years', 'NOUN', 'year'),
#  ('Recession', 'NOUN', 'recession'),
#  ('fears', 'NOUN', 'fear'),
#  ('swelled', 'VERB', 'swell'),
#  ('yield', 'NOUN', 'yield'),
#  ('curve', 'NOUN', 'curve'),
#  ('inverted', 'VERB', 'invert'),
#  ('Investors', 'NOUN', 'investor'),
#  ('began', 'VERB', 'begin'),
#  ('considered', 'VERB', 'considered'),
#  ('$', 'SYM', '$'),
#  ('17', 'NUM', '17'),
#  ('trillion', 'NUM', 'trillion'),
#  ('pile', 'NOUN', 'pile'),
#  ('negative', 'ADJ', 'negative'),
#  ('yielding', 'VERB', 'yield'),
#  ('debt', 'NOUN', 'debt'),
#  ('sovereign', 'ADJ', 'sovereign'),
#  ('nations', 'NOUN', 'nation'),
#  ('Europe', 'PROPN', 'Europe'),
#  ('negative', 'ADJ', 'negative'),
#  ('yielding', 'VERB', 'yield'),
#  ('bond', 'NOUN', 'bond'),
#  ('yield', 'NOUN', 'yield'),
#  ('zero', 'NUM', 'zero'),
#  ('held', 'VERB', 'hold'),
#  ('maturity', 'NOUN', 'maturity'),
#  ('year', 'NOUN', 'year'),
#  ('progressed', 'VERB', 'progress'),
#  ('bond', 'NOUN', 'bond'),
#  ('markets', 'NOUN', 'market'),
#  ('stabilized', 'VERB', 'stabilize'),
#  ('yield', 'NOUN', 'yield'),
#  ('curve', 'NOUN', 'curve'),
#  ('investors', 'NOUN', 'investor'),
#  ('feared', 'VERB', 'fear'),
#  ('finally', 'ADV', 'finally'),
#  ('steepened', 'VERB', 'steepen'),
#  ('optimism', 'NOUN', 'optimism'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('economy', 'NOUN', 'economy'),
#  ('slow', 'VERB', 'slow'),
#  ('expected', 'VERB', 'expect'),
#  ('expectations', 'NOUN', 'expectation'),
#  ('Federal', 'PROPN', 'Federal'),
#  ('Reserve', 'PROPN', 'Reserve'),
#  ('hold', 'VERB', 'hold'),
#  ('benchmark', 'ADJ', 'benchmark'),
#  ('interest', 'NOUN', 'interest'),
#  ('rate', 'NOUN', 'rate'),
#  ('current', 'ADJ', 'current'),
#  ('level', 'NOUN', 'level'),
#  ('cutting', 'VERB', 'cut'),
#  ('times', 'NOUN', 'time'),
#  ('year', 'NOUN', 'year'),
#  ('spread', 'NOUN', 'spread'),
#  ('2-year', 'NUM', '2-year'),
#  ('10-year', 'NUM', '10-year'),
#  ('Treasuries', 'NOUN', 'treasury'),
#  ('widened', 'VERB', 'widen'),
#  ('highest', 'ADJ', 'high'),
#  ('level', 'NOUN', 'level'),
#  ('October', 'PROPN', 'October'),
#  ('indicating', 'VERB', 'indicate'),
#  ('investors', 'NOUN', 'investor'),
#  ('believe', 'VERB', 'believe'),
#  ('global', 'ADJ', 'global'),
#  ('growth', 'NOUN', 'growth'),
#  ('scare', 'NOUN', 'scare'),
#  ('mitigated', 'VERB', 'mitigate'),
#  ('rate', 'NOUN', 'rate'),
#  ('cuts', 'NOUN', 'cut'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('central', 'ADJ', 'central'),
#  ('banks', 'NOUN', 'bank'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('manufacturers', 'NOUN', 'manufacturer'),
#  ('sent', 'VERB', 'send'),
#  ('warning', 'NOUN', 'warning'),
#  ('signs', 'NOUN', 'sign'),
#  ('2019', 'NUM', '2019'),
#  ('Institute', 'PROPN', 'Institute'),
#  ('Supply', 'PROPN', 'Supply'),
#  ('Management', 'PROPN', 'Management'),
#  ('reported', 'VERB', 'report'),
#  ('manufacturing', 'VERB', 'manufacture'),
#  ('activity', 'NOUN', 'activity'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('contracted', 'VERB', 'contract'),
#  ('fourth', 'ADJ', 'fourth'),
#  ('straight', 'ADJ', 'straight'),
#  ('month', 'NOUN', 'month'),
#  ('November', 'PROPN', 'November'),
#  ('manufacturing', 'NOUN', 'manufacturing'),
#  ('contraction', 'NOUN', 'contraction'),
#  ('key', 'ADJ', 'key'),
#  ('economic', 'ADJ', 'economic'),
#  ('slowdown', 'NOUN', 'slowdown'),
#  ('narrative', 'NOUN', 'narrative'),
#  ('hand', 'NOUN', 'hand'),
#  ('ISM', 'PROPN', 'ISM'),
#  ('non', 'ADJ', 'non'),
#  ('-', 'ADJ', '-'),
#  ('manufacturing', 'ADJ', 'manufacturing'),
#  ('index', 'NOUN', 'index'),
#  ('continues', 'VERB', 'continue'),
#  ('expand', 'VERB', 'expand'),
#  ('meaning', 'VERB', 'mean'),
#  ('service', 'NOUN', 'service'),
#  ('sector', 'NOUN', 'sector'),
#  ('running', 'VERB', 'run'),
#  ('strong', 'ADJ', 'strong'),
#  ('negative', 'ADJ', 'negative'),
#  ('turns', 'VERB', 'turn'),
#  ('economic', 'ADJ', 'economic'),
#  ('data', 'NOUN', 'datum'),
#  ('took', 'VERB', 'take'),
#  ('2019', 'NUM', '2019'),
#  ('offset', 'VERB', 'offset'),
#  ('strong', 'ADJ', 'strong'),
#  ('consumer', 'NOUN', 'consumer'),
#  ('spending', 'NOUN', 'spending'),
#  ('historically', 'ADV', 'historically'),
#  ('low', 'ADJ', 'low'),
#  ('unemployment', 'NOUN', 'unemployment'),
#  ('rate', 'NOUN', 'rate'),
#  ('currently', 'ADV', 'currently'),
#  ('3.5', 'NUM', '3.5'),
#  ('percent', 'NOUN', 'percent'),
#  ('stocks', 'NOUN', 'stock'),
#  ('accounted', 'VERB', 'account'),
#  ('nearly', 'ADV', 'nearly'),
#  ('15', 'NUM', '15'),
#  ('%', 'NOUN', '%'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('500', 'NUM', '500'),
#  ('gains', 'NOUN', 'gain'),
#  ('according', 'VERB', 'accord'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('Dow', 'PROPN', 'Dow'),
#  ('Jones', 'PROPN', 'Jones'),
#  ('Indices', 'PROPN', 'Indices'),
#  ('Apple', 'PROPN', 'Apple'),
#  ('85', 'NUM', '85'),
#  ('%', 'NOUN', '%'),
#  ('Microsoft', 'PROPN', 'Microsoft'),
#  ('15', 'NUM', '15'),
#  ('%', 'NOUN', '%'),
#  (' ', 'SPACE', ' '),
#  ('tech', 'NOUN', 'tech'),
#  ('giants', 'NOUN', 'giant'),
#  ('U.S.', 'PROPN', 'U.S.'),
#  ('companies', 'NOUN', 'company'),
#  ('market', 'NOUN', 'market'),
#  ('capitalization', 'NOUN', 'capitalization'),
#  ('$', 'SYM', '$'),
#  ('1', 'NUM', '1'),
#  ('trillion', 'NUM', 'trillion'),
#  ('cap', 'NOUN', 'cap'),
#  ('weighted', 'VERB', 'weight'),
#  ('index', 'NOUN', 'index'),
#  ('like', 'SCONJ', 'like'),
#  ('S&P', 'PROPN', 'S&P'),
#  ('outsized', 'ADJ', 'outsized'),
#  ('influence', 'NOUN', 'influence'),
#  ('Facebook', 'PROPN', 'Facebook'),
#  ('Alphabet', 'PROPN', 'Alphabet'),
#  ('Google', 'PROPN', 'Google'),
#  ('parent', 'NOUN', 'parent'),
#  ('company', 'NOUN', 'company'),
#  ('Amazon', 'PROPN', 'Amazon'),
#  ('contributed', 'VERB', 'contribute'),
#  ('Semiconductor', 'NOUN', 'semiconductor'),
#  ('companies', 'NOUN', 'company'),
#  ('big', 'ADJ', 'big'),
#  ('gainers', 'NOUN', 'gainer'),
#  ('Advance', 'PROPN', 'Advance'),
#  ('Micro', 'PROPN', 'Micro'),
#  ('Devices', 'PROPN', 'Devices'),
#  ('Lam', 'PROPN', 'Lam'),
#  ('Research', 'PROPN', 'Research'),
#  ('KLA', 'PROPN', 'KLA'),
#  ('Corp.', 'PROPN', 'Corp.'),
#  ('leading', 'VERB', 'lead'),
#  ('index', 'NOUN', 'index'),
#  ('largest', 'ADJ', 'large'),
#  ('gains', 'NOUN', 'gain'),
#  (' ', 'SPACE', ' '),
#  ('end', 'NOUN', 'end'),
#  ('2019', 'NUM', '2019'),
#  ('enjoyed', 'VERB', 'enjoy'),
#  ('confluence', 'NOUN', 'confluence'),
#  ('booming', 'VERB', 'boom'),
#  ('technology', 'NOUN', 'technology'),
#  ('easy', 'ADJ', 'easy'),
#  ('money', 'NOUN', 'money'),
#  ('Fed', 'PROPN', 'Fed'),
#  ('proved', 'VERB', 'prove'),
#  ('age', 'NOUN', 'age'),
#  ('old', 'ADJ', 'old'),
#  ('Wall', 'PROPN', 'Wall'),
#  ('Street', 'PROPN', 'Street'),
#  ('maxim', 'NOUN', 'maxim'),
#  ('markets', 'NOUN', 'market'),
#  ('climb', 'VERB', 'climb'),
#  ('wall', 'NOUN', 'wall'),
#  ('worry', 'NOUN', 'worry'),
#  ('year', 'NOUN', 'year'),
#  ('Got', 'VERB', 'get'),
#  ('confidential', 'ADJ', 'confidential'),
#  ('news', 'NOUN', 'news'),
#  ('tip', 'NOUN', 'tip'),
#  ('want', 'VERB', 'want'),
#  ('hear', 'VERB', 'hear'),
#  ('Sign', 'VERB', 'sign'),
#  ('free', 'ADJ', 'free'),
#  ('newsletters', 'NOUN', 'newsletter'),
#  ('CNBC', 'PROPN', 'CNBC'),
#  ('delivered', 'VERB', 'deliver'),
#  ('inbox', 'NOUN', 'inbox'),
#  ('delivered', 'VERB', 'deliver'),
#  ('inbox', 'NOUN', 'inbox'),
#  ('info', 'NOUN', 'info'),
#  ('products', 'NOUN', 'product'),
#  ('services', 'NOUN', 'service'),
#  ('\xa0 ', 'SPACE', '\xa0 '),
#  ('©', 'PROPN', '©'),
#  ('2022', 'NUM', '2022'),
#  ('CNBC', 'PROPN', 'CNBC'),
#  ('LLC', 'PROPN', 'LLC'),
#  ('Rights', 'PROPN', 'Rights'),
#  ('Reserved', 'PROPN', 'Reserved'),
#  ('Division', 'PROPN', 'Division'),
#  ('NBCUniversal', 'PROPN', 'NBCUniversal'),
#  ('Data', 'PROPN', 'Data'),
#  ('real', 'ADJ', 'real'),
#  ('time', 'NOUN', 'time'),
#  ('snapshot', 'NOUN', 'snapshot'),
#  ('Data', 'PROPN', 'Data'),
#  ('delayed', 'VERB', 'delay'),
#  ('15', 'NUM', '15'),
#  ('minutes', 'NOUN', 'minute'),
#  ('Global', 'PROPN', 'Global'),
#  ('Business', 'PROPN', 'Business'),
#  ('Financial', 'PROPN', 'Financial'),
#  ('News', 'PROPN', 'News'),
#  ('Stock', 'PROPN', 'Stock'),
#  ('Quotes', 'PROPN', 'Quotes'),
#  ('Market', 'PROPN', 'Market'),
#  ('Data', 'PROPN', 'Data'),
#  ('Analysis', 'PROPN', 'Analysis'),
#  ('Data', 'NOUN', 'datum'),
#  ('provided', 'VERB', 'provide'),
#  (' ', 'SPACE', ' ')]

# %%
# NER using BERT Hugging Face
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
generator = pipeline("ner",
                     model=model,
                     tokenizer=tokenizer,
                     grouped_entities=True)

# print words 'organization'
for x in generator(content):
  for key, value in x.items():
     if value=='ORG':
       print (x)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   f'`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="{aggregation_strategy}"` instead.'
# {'entity_group': 'ORG', 'score': 0.99783033, 'word': 'Apple', 'start': 455, 'end': 460}
# {'entity_group': 'ORG', 'score': 0.9978947, 'word': 'Microsoft', 'start': 465, 'end': 474}
# {'entity_group': 'ORG', 'score': 0.982275, 'word': 'Federal Reserve', 'start': 698, 'end': 713}
# {'entity_group': 'ORG', 'score': 0.9968617, 'word': 'S & P', 'start': 1233, 'end': 1236}
# {'entity_group': 'ORG', 'score': 0.89660454, 'word': 'P', 'start': 1348, 'end': 1349}
# {'entity_group': 'ORG', 'score': 0.9968209, 'word': 'Federal Reserve', 'start': 1470, 'end': 1485}
# {'entity_group': 'ORG', 'score': 0.9983499, 'word': 'Fed', 'start': 1491, 'end': 1494}
# {'entity_group': 'ORG', 'score': 0.996633, 'word': 'Fed', 'start': 1665, 'end': 1668}
# {'entity_group': 'ORG', 'score': 0.99665403, 'word': 'Fed', 'start': 1838, 'end': 1841}
# {'entity_group': 'ORG', 'score': 0.9967719, 'word': 'Fed', 'start': 1913, 'end': 1916}
# {'entity_group': 'ORG', 'score': 0.9969798, 'word': 'Fed', 'start': 2043, 'end': 2046}
# {'entity_group': 'ORG', 'score': 0.9801214, 'word': 'Powell', 'start': 2063, 'end': 2069}
# {'entity_group': 'ORG', 'score': 0.9968401, 'word': 'Fed', 'start': 2135, 'end': 2138}
